# %% [markdown]
# # POS tagging using modified Viterbi
#
# ## Objectives of the analysis -
#
# - Write the vanilla Viterbi algorithm for assigning POS tags (i.e. without dealing with unknown words)
#
# - Solve the problem of unknown words using at least two techniques.
#
# - Compare the tagging accuracy after making these modifications with the vanilla Viterbi algorithm.
#
# - List down at least three cases from the sample test file (i.e. unknown word-tag pairs) which were
#   incorrectly tagged by the original Viterbi POS tagger and got corrected after your modifications.

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries

import nltk, re
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download("stopwords")
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# True

# %%
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %% [markdown]
# ## Data Preparation

# %%
nltk_data[:2]
# Out:
# [[('Pierre', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   (',', '.'),
#   ('61', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('join', 'VERB'),
#   ('the', 'DET'),
#   ('board', 'NOUN'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('nonexecutive', 'ADJ'),
#   ('director', 'NOUN'),
#   ('Nov.', 'NOUN'),
#   ('29', 'NUM'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   ('is', 'VERB'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('Elsevier', 'NOUN'),
#   ('N.V.', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Dutch', 'NOUN'),
#   ('publishing', 'VERB'),
#   ('group', 'NOUN'),
#   ('.', '.')]]

# %%
# Splitting into train and test
random.seed(1234)
train_set, test_set = train_test_split(nltk_data, test_size=0.05)

print("Training Set Length -", len(train_set))
print("Training Set Length -", len(test_set))
print("-" * 120)
print("Training Data Glimpse -\n")
print(train_set[:10])
# Out:
# Training Set Length - 3718
# Training Set Length - 196
# ------------------------------------------------------------------------------------------------------------------------
# Training Data Glimpse -
#
# [[('``', '.'), ('Professional', 'ADJ'), ('sugar', 'NOUN'), ('people', 'NOUN'), ('here', 'ADV'), ('who', 'PRON'), ('*T*-1', 'X'), ('have', 'VERB'), ('strong', 'ADJ'), ('contacts', 'NOUN'), ('with', 'ADP'), ('the', 'DET'), ('Brazilian', 'ADJ'), ('sugar', 'NOUN'), ('industry', 'NOUN'), ('have', 'VERB'), ('been', 'VERB'), ('unable', 'ADJ'), ('*-3', 'X'), ('to', 'PRT'), ('confirm', 'VERB'), ('the', 'DET'), ('reports', 'NOUN'), ('or', 'CONJ'), ('get', 'VERB'), ('enough', 'ADJ'), ('information', 'NOUN'), ('0', 'X'), ('*', 'X'), ('to', 'PRT'), ('clarify', 'VERB'), ('the', 'DET'), ('situation', 'NOUN'), ('*T*-4', 'X'), (',', '.'), ("''", '.'), ('he', 'PRON'), ('said', 'VERB'), ('*T*-2', 'X'), ('.', '.')], [('We', 'PRON'), ('also', 'ADV'), ('know', 'VERB'), ('that', 'ADP'), ('the', 'DET'), ('tort', 'NOUN'), ('system', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('lousy', 'ADJ'), ('way', 'NOUN'), ('0', 'X'), ('*', 'X'), ('to', 'PRT'), ('compensate', 'VERB'), ('victims', 'NOUN'), ('*T*-1', 'X'), ('anyway', 'ADV'), (';', '.'), ('some', 'DET'), ('win', 'VERB'), ('the', 'DET'), ('legal', 'ADJ'), ('lottery', 'NOUN'), (',', '.'), ('others', 'NOUN'), ('get', 'VERB'), ('much', 'ADV'), ('less', 'ADJ'), ('and', 'CONJ'), ('contingency-fee', 'ADJ'), ('lawyers', 'NOUN'), ('take', 'VERB'), ('a', 'DET'), ('big', 'ADJ'), ('cut', 'NOUN'), ('either', 'DET'), ('way', 'NOUN'), ('.', '.')], [('Any', 'DET'), ('reading', 'NOUN'), ('below', 'ADP'), ('50', 'NUM'), ('%', 'NOUN'), ('suggests', 'VERB'), ('0', 'X'), ('the', 'DET'), ('manufacturing', 'NOUN'), ('sector', 'NOUN'), ('is', 'VERB'), ('generally', 'ADV'), ('declining', 'VERB'), ('.', '.')], [('If', 'ADP'), ('he', 'PRON'), ('does', 'VERB'), ('not', 'ADV'), (',', '.'), ('he', 'PRON'), ('will', 'VERB'), ('help', 'VERB'), ('*-1', 'X'), ('realize', 'VERB'), ('Madison', 'NOUN'), ("'s", 'PRT'), ('fear', 'NOUN'), ('in', 'ADP'), ('The', 'DET'), ('Federalist', 'NOUN'), ('No.', 'NOUN'), ('48', 'NUM'), ('of', 'ADP'), ('a', 'DET'), ('legislature', 'NOUN'), ('``', '.'), ('everywhere', 'ADV'), ('extending', 'VERB'), ('the', 'DET'), ('sphere', 'NOUN'), ('of', 'ADP'), ('its', 'PRON'), ('activity', 'NOUN'), ('and', 'CONJ'), ('drawing', 'VERB'), ('all', 'DET'), ('powers', 'NOUN'), ('into', 'ADP'), ('its', 'PRON'), ('impetuous', 'ADJ'), ('vortex', 'NOUN'), ('.', '.'), ("''", '.')], [('Centerbank', 'NOUN'), ('added', 'VERB'), ('5\\/8', 'NUM'), ('to', 'PRT'), ('8', 'NUM'), ('3\\/4', 'NUM'), (';', '.'), ('shares', 'NOUN'), ('of', 'ADP'), ('NESB', 'NOUN'), (',', '.'), ('a', 'DET'), ('New', 'NOUN'), ('London-based', 'ADJ'), ('bank', 'NOUN'), ('holding', 'VERB'), ('company', 'NOUN'), (',', '.'), ('rose', 'VERB'), ('5\\/8', 'NUM'), ('to', 'PRT'), ('5', 'NUM'), ('7\\/8', 'NUM'), ('.', '.')], [('It', 'PRON'), ('was', 'VERB'), ('censorship', 'NOUN'), ('.', '.')], [('That', 'DET'), ('pattern', 'NOUN'), ('has', 'VERB'), ("n't", 'ADV'), ('always', 'ADV'), ('held', 'VERB'), (',', '.'), ('but', 'CONJ'), ('recent', 'ADJ'), ('strong', 'ADJ'), ('growth', 'NOUN'), ('in', 'ADP'), ('dividends', 'NOUN'), ('makes', 'VERB'), ('some', 'DET'), ('market', 'NOUN'), ('watchers', 'NOUN'), ('anxious', 'ADJ'), ('.', '.')], [('He', 'PRON'), ('has', 'VERB'), ('a', 'DET'), ('point', 'NOUN'), ('0', 'X'), ('he', 'PRON'), ('wants', 'VERB'), ('*-1', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('*T*-2', 'X'), (',', '.'), ('and', 'CONJ'), ('he', 'PRON'), ('makes', 'VERB'), ('it', 'PRON'), (',', '.'), ('with', 'ADP'), ('a', 'DET'), ('great', 'ADJ'), ('deal', 'NOUN'), ('of', 'ADP'), ('force', 'NOUN'), ('.', '.')], [('The', 'DET'), ('AT&T', 'NOUN'), ('team', 'NOUN'), ('also', 'ADV'), ('is', 'VERB'), ('trying', 'VERB'), ('*-1', 'X'), ('to', 'PRT'), ('combine', 'VERB'), ('their', 'PRON'), ('latest', 'ADJ'), ('superconductor', 'NOUN'), ('process', 'NOUN'), ('with', 'ADP'), ('``', '.'), ('melt-textured', 'ADJ'), ('growth', 'NOUN'), (',', '.'), ("''", '.'), ('a', 'DET'), ('process', 'NOUN'), ('discovered', 'VERB'), ('*', 'X'), ('earlier', 'ADJ'), ('at', 'ADP'), ('Bell', 'NOUN'), ('La ...

# %%
# Getting list of tagged words

train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)
# Out:
# 95836

# %%
# Let's have a look at the tagged words in the training set

train_tagged_words[:10]
# Out:
# [('``', '.'),
#  ('Professional', 'ADJ'),
#  ('sugar', 'NOUN'),
#  ('people', 'NOUN'),
#  ('here', 'ADV'),
#  ('who', 'PRON'),
#  ('*T*-1', 'X'),
#  ('have', 'VERB'),
#  ('strong', 'ADJ'),
#  ('contacts', 'NOUN')]

# %%
# tokens in the train set - train_tagged_words

train_data_tokens = [pair[0] for pair in train_tagged_words]
train_data_tokens[:10]
# Out:
# ['``',
#  'Professional',
#  'sugar',
#  'people',
#  'here',
#  'who',
#  '*T*-1',
#  'have',
#  'strong',
#  'contacts']

# %%
# POS tags for the tokens in the train set -

train_data_pos_tags = [pair[1] for pair in train_tagged_words]
train_data_pos_tags[:10]
# Out:
# ['.', 'ADJ', 'NOUN', 'NOUN', 'ADV', 'PRON', 'X', 'VERB', 'ADJ', 'NOUN']

# %%
# building the train vocabulary to a set

training_vocabulary_set = set(train_data_tokens)

# %%
# building the POS tags to a set

training_pos_tag_set = set(train_data_pos_tags)

# %%
print("Length : \nVocabulary: {} \nTags: {}".format(len(training_vocabulary_set), len(training_pos_tag_set)))
print("\nAvailable Tags :\n")
print(training_pos_tag_set)
# Out:
# Length :
# Vocabulary: 12104
# Tags: 12
#
# Available Tags :
#
# {'ADV', 'DET', 'ADJ', 'NUM', 'NOUN', 'CONJ', 'PRON', 'X', 'ADP', '.', 'PRT', 'VERB'}

# %% [markdown]
# ## Emission and Transition Probabilities

# %%
# computing P(w/t) and storing in [Tags x Vocabulary] matrix. This is a matrix with dimension
# of len(training_pos_tag_set) X en(training_vocabulary_set)

len_pos_tags = len(training_pos_tag_set)
len_vocab = len(training_vocabulary_set)

word_given_tag = np.zeros((len_pos_tags, len_vocab))

# %%
# compute word given tag: Emission Probability

def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len_pos_tags, len_pos_tags), dtype='float32')
for i, t1 in enumerate(list(training_pos_tag_set)):
    for j, t2 in enumerate(list(training_pos_tag_set)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# Let's have a glimpse into the transition matrix
tags_matrix
# Out:
# array([[8.0947682e-02, 6.9759786e-02, 1.3030602e-01, 3.1260282e-02,
#         3.2247450e-02, 7.2392235e-03, 1.5136558e-02, 2.3033893e-02,
#         1.1681474e-01, 1.3524185e-01, 1.4807503e-02, 3.4320500e-01],
#        [1.3030888e-02, 5.6708492e-03, 2.0390926e-01, 2.1597490e-02,
#         6.3911682e-01, 4.8262547e-04, 3.6196911e-03, 4.5487452e-02,
#         9.1698840e-03, 1.7736487e-02, 2.4131274e-04, 3.9937258e-02],
#        [4.7611231e-03, 4.9252994e-03, 6.7312427e-02, 2.0522082e-02,
#         7.0004928e-01, 1.7074373e-02, 6.5670663e-04, 2.1178788e-02,
#         7.6998852e-02, 6.3372187e-02, 1.0999836e-02, 1.2149072e-02],
#        [2.9647199e-03, 3.5576639e-03, 3.2611918e-02, 1.8381263e-01,
#         3.5220870e-01, 1.3934183e-02, 1.4823599e-03, 2.1049511e-01,
#         3.5280164e-02, 1.1858879e-01, 2.6682479e-02, 1.8381262e-02],
#        [1.6848003e-02, 1.3209126e-02, 1.2335796e-02, 9.5702484e-03,
#         2.6429170e-01, 4.2138204e-02, 4.5485971e-03, 2.8783523e-02,
#         1.7604890e-01, 2.4071176e-01, 4.4357918e-02, 1.4715622e-01],
#        [5.7209302e-02, 1.1906977e-01, 1.2000000e-01, 4.1860465e-02,
#         3.4790698e-01, 4.6511629e-04, 5.8139537e-02, 8.3720926e-03,
#         5.3023256e-02, 3.4883723e-02, 4.6511628e-03, 1.5441860e-01],
#        [3.3166219e-02, 1.0026996e-02, 7.3659852e-02, 7.3274202e-03,
#         2.1172388e-01, 5.3991517e-03, 7.7130739e-03, 9.3713842e-02,
#         2.2753567e-02, 4.0879291e-02, 1.2726571e-02, 4.8091015e-01],
#        [2.5567731e-02, 5.5264413e-02, 1.6039385e-02, 2.8585040e-03,
#         6.1775450e-02, 1.0322376e-02, 5.5423219e-02, 7.4321106e-02,
#         1.4403684e-01, 1.6531682e-01, 1.8373829e-01, 2.0533587e-01],
#        [1.3878509e-02, 3.2358280e-01, 1.0686453e-01, 6.3414112e-02,
#         3.2112736e-01, 7.4730435e-04, 6.8324968e-02, 3.4909789e-02,
#         1.7401516e-02, 3.9927404e-02, 1.3878510e-03, 8.4338635e-03],
#        [5.2979540e-02, 1.7233986e-01, 4.3956045e-02, 8.0496736e-02,
#         2.2317520e-01, 5.8161352e-02, 6.5755382e-02, 2.7338516e-02,
#         9.0413652e-02, 9.4076656e-02, 2.5015634e-03, 8.8716164e-02],
#        [9.7783571e-03, 1.0006519e-01, 8.6375490e-02, 5.6714471e-02,
#         2.5000000e-01, 2.2816167e-03, 1.7601043e-02, 1.3037810e-02,
#         2.0208605e-02, 4.3350719e-02, 1.6297263e-03, 3.9895698e-01],
#        [8.2196027e-02, 1.3391750e-01, 6.4981386e-02, 2.2875311e-02,
#         1.0949132e-01, 5.4280399e-03, 3.5592433e-02, 2.1851736e-01,
#         9.2509307e-02, 3.4972083e-02, 3.0939827e-02, 1.6857940e-01]],
#       dtype=float32)

# %%
# convert the matrix to a data frame for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(training_pos_tag_set), index=list(training_pos_tag_set))

# dataset glimpse
tags_df
# Out:
#            ADV       DET       ADJ       NUM      NOUN      CONJ      PRON  \
# ADV   0.080948  0.069760  0.130306  0.031260  0.032247  0.007239  0.015137
# DET   0.013031  0.005671  0.203909  0.021597  0.639117  0.000483  0.003620
# ADJ   0.004761  0.004925  0.067312  0.020522  0.700049  0.017074  0.000657
# NUM   0.002965  0.003558  0.032612  0.183813  0.352209  0.013934  0.001482
# NOUN  0.016848  0.013209  0.012336  0.009570  0.264292  0.042138  0.004549
# CONJ  0.057209  0.119070  0.120000  0.041860  0.347907  0.000465  0.058140
# PRON  0.033166  0.010027  0.073660  0.007327  0.211724  0.005399  0.007713
# X     0.025568  0.055264  0.016039  0.002859  0.061775  0.010322  0.055423
# ADP   0.013879  0.323583  0.106865  0.063414  0.321127  0.000747  0.068325
# .     0.052980  0.172340  0.043956  0.080497  0.223175  0.058161  0.065755
# PRT   0.009778  0.100065  0.086375  0.056714  0.250000  0.002282  0.017601
# VERB  0.082196  0.133917  0.064981  0.022875  0.109491  0.005428  0.035592
#
#              X       ADP         .       PRT      VERB
# ADV   0.023034  0.116815  0.135242  0.014808  0.343205
# DET   0.045487  0.009170  0.017736  0.000241  0.039937
# ADJ   0.021179  0.076999  0.063372  0.011000  0.012149
# NUM   0.210495  0.035280  0.118589  0.026682  0.018381
# NOUN  0.028784  0.176049  0.240712  0.044358  0.147156
# CONJ  0.008372  0.053023  0.034884  0.004651  0.154419
# PRON  0.093714  0.022754  0.040879  0.012727  0.480910
# X     0.074321  0.144037  0.165317  0.183738  0.205336
# ADP   0.034910  0.017402  0.039927  0.001388  0.008434
# .     0.027339  0.090414  0.094077  0.002502  0.088716
# PRT   0.013038  0.020209  0.043351  0.001630  0.398957
# VERB  0.218517  0.092509  0.034972  0.030940  0.168579

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# heatmap of tags matrix
# T(i, j) means P(tag j given tag i)
plt.figure(figsize=(14, 8))
sns.heatmap(tags_df, annot = True)
plt.show()

# %%
# frequent tags
# filter the df to get P(t2, t1) > 0.5

tags_frequent = tags_df[tags_df>0.5]
plt.figure(figsize=(14, 8))
sns.heatmap(tags_frequent, annot = True)
plt.show()

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# Viterbi Heuristic
def Vanilla_Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
random.seed(1234)

# list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]

# list of untagged words
test_tagged_words = [tup[0] for sent in test_set for tup in sent]

# %%
# tagging the test sentences

tagged_seq = Vanilla_Viterbi(test_tagged_words)

# %%
# Let's check the accuracy of the vanilla viterbi algorithm

check = [i for i, j in zip(tagged_seq, test_run_base) if i == j]

vanilla_viterbi_accuracy = len(check)/len(tagged_seq)

print("The accuracy of the Vanilla Viterbi Algorithm is -", vanilla_viterbi_accuracy)
# Out:
# The accuracy of the Vanilla Viterbi Algorithm is - 0.9076446280991736

# %%
# Let's have a look at the incorrect tagged cases

incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
print(len(incorrect_tagged_cases))
incorrect_tagged_cases
# Out:
# 447
# [[('``', '.'), (('filled', 'ADV'), ('filled', 'VERB'))],
#  [('the', 'DET'), (('solemn', 'ADV'), ('solemn', 'ADJ'))],
#  [('solemn', 'ADJ'), (('intoxication', 'ADV'), ('intoxication', 'NOUN'))],
#  [('intoxication', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-226', 'ADV'), ('*T*-226', 'X'))],
#  [('of', 'ADP'), (('intricate', 'ADV'), ('intricate', 'ADJ'))],
#  [('intricate', 'ADJ'), (('ritual', 'ADV'), ('ritual', 'NOUN'))],
#  [('annually', 'ADV'), (('total', 'ADJ'), ('total', 'VERB'))],
#  [('$', '.'), (('38.3', 'ADV'), ('38.3', 'NUM'))],
#  [('.', '.'), (('Close', 'ADV'), ('Close', 'ADJ'))],
#  [('Close', 'ADJ'), (('parallels', 'VERB'), ('parallels', 'NOUN'))],
#  [('*U*', 'X'), (('pretax', 'NOUN'), ('pretax', 'ADJ'))],
#  [('citing', 'VERB'), (('extended', 'VERB'), ('extended', 'ADJ'))],
#  [('market', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('to', 'PRT'), (('switch', 'NOUN'), ('switch', 'VERB'))],
#  [('more', 'ADJ'), (('economical', 'ADV'), ('economical', 'ADJ'))],
#  [('$', '.'), (('3.80', 'ADV'), ('3.80', 'NUM'))],
#  [('the', 'DET'), (('third-largest', 'ADV'), ('third-largest', 'ADJ'))],
#  [('the', 'DET'), (('fifth-largest', 'ADV'), ('fifth-largest', 'ADJ'))],
#  [('.', '.'), (('Billings', 'ADV'), ('Billings', 'NOUN'))],
#  [('which', 'DET'), (('*T*-155', 'ADV'), ('*T*-155', 'X'))],
#  [('been', 'VERB'), (('serviced', 'ADV'), ('serviced', 'VERB'))],
#  [('The', 'DET'), (('CEO', 'ADV'), ('CEO', 'NOUN'))],
#  [('CEO', 'NOUN'), (('succession', 'ADV'), ('succession', 'NOUN'))],
#  [('take', 'VERB'), (('early', 'ADV'), ('early', 'ADJ'))],
#  [('its', 'PRON'), (('leasing', 'ADV'), ('leasing', 'NOUN'))],
#  [('another', 'DET'), (('layer', 'ADV'), ('layer', 'NOUN'))],
#  [('A', 'DET'), (('disaffected', 'ADV'), ('disaffected', 'ADJ'))],
#  [(',', '.'), (('hard-drinking', 'ADV'), ('hard-drinking', 'ADJ'))],
#  [(',', '.'), (('nearly-30', 'ADV'), ('nearly-30', 'ADJ'))],
#  [('hero', 'NOUN'), (('sets', 'NOUN'), ('sets', 'VERB'))],
#  [('for', 'ADP'), (('snow', 'ADV'), ('snow', 'NOUN'))],
#  [('in', 'ADP'), (('search', 'ADV'), ('search', 'NOUN'))],
#  [('an', 'DET'), (('elusive', 'ADV'), ('elusive', 'ADJ'))],
#  [('elusive', 'ADJ'), (('sheep', 'ADV'), ('sheep', 'NOUN'))],
#  [('its', 'PRON'), (('back', 'ADV'), ('back', 'NOUN'))],
#  [('the', 'DET'), (('behest', 'ADV'), ('behest', 'NOUN'))],
#  [('a', 'DET'), (('sinister', 'ADV'), ('sinister', 'ADJ'))],
#  [(',', '.'), (('erudite', 'ADV'), ('erudite', 'ADJ'))],
#  [('erudite', 'ADJ'), (('mobster', 'ADV'), ('mobster', 'NOUN'))],
#  [('Stanford', 'NOUN'), (('degree', 'ADV'), ('degree', 'NOUN'))],
#  [('regulated', 'VERB'), (('*-134', 'ADV'), ('*-134', 'X'))],
#  [('which', 'DET'), (('*T*-218', 'ADV'), ('*T*-218', 'X'))],
#  [('*T*-218', 'X'), (('reports', 'NOUN'), ('reports', 'VERB'))],
#  [('Agriculture', 'NOUN'), (('committees', 'ADV'), ('committees', 'NOUN'))],
#  [('with', 'ADP'), (('thin-lipped', 'ADV'), ('thin-lipped', 'ADJ'))],
#  [('by', 'ADP'), (('Isabelle', 'ADV'), ('Isabelle', 'NOUN'))],
#  [('Isabelle', 'NOUN'), (('Huppert', 'ADV'), ('Huppert', 'NOUN'))],
#  [('*', 'X'), (('Marie', 'ADV'), ('Marie', 'NOUN'))],
#  [('the', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('playing', 'VERB'), (('catch-up', 'ADV'), ('catch-up', 'NOUN'))],
#  [('the', 'DET'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('unit', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-7', 'ADV'), ('*T*-7', 'X'))],
#  [('made', 'VERB'), (('vinyl', 'ADV'), ('vinyl', 'NOUN'))],
#  [('vinyl', 'NOUN'), (('checkbook', 'ADV'), ('checkbook', 'NOUN'))],
#  [('checkbook', 'NOUN'), (('covers', 'VERB'), ('covers', 'NOUN'))],
#  [('about', 'ADP'), (('3,600', 'ADV'), ('3,600', 'NUM'))],
#  [('a', 'DET'), (('Hamilton', 'ADV'), ('Hamilton', 'NOUN'))],
#  [(',', '.'), (('Bermuda-based', 'ADV'), ('Bermuda-based', 'ADJ'))],
#  [('Bermuda-based', 'ADJ'), (('shipping', 'VERB'), ('shipping', 'NOUN'))],
#  [('the', 'DET'), (('municipality', 'ADV'), ('municipality', 'NOUN'))],
#  [('R.', 'NOUN'), (('Breakey', 'ADV'), ('Breakey', 'NOUN'))],
#  [('J.', 'NOUN'), (('Fischer', 'ADV'), ('Fischer', 'NOUN'))],
#  [('of', 'ADP'), (('Psychiatry', 'ADV'), ('Psychiatry', 'NOUN'))],
#  [('Psychiatry', 'NOUN'), (('Johns', 'ADV'), ('Johns', 'NOUN'))],
#  [('Johns', 'NOUN'), (('Hopkins', 'ADV'), ('Hopkins', 'NOUN'))],
#  [('the', 'DET'), (('H.N.', 'ADV'), ('H.N.', 'NOUN'))],
#  [('&', 'CONJ'), (('Frances', 'ADV'), ('Frances', 'NOUN'))],
#  [('C.', 'NOUN'), (('Berger', 'ADV'), ('Berger', 'NOUN'))],
#  [('drug', 'NOUN'), (('trafficking', 'ADV'), ('trafficking', 'NOUN'))],
#  [('the', 'DET'), (('Andean', 'ADV'), ('Andean', 'ADJ'))],
#  [('Taking', 'VERB'), (('over', 'ADP'), ('over', 'PRT'))],
#  [('over', 'PRT'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('chief', 'NOUN'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('he', 'PRON'), (('inherited', 'ADV'), ('inherited', 'VERB'))],
#  [('company', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('a', 'DET'),
#   (('recession-inspired', 'ADV'), ('recession-inspired', 'ADJ'))],
#  [('recession-inspired', 'ADJ'), (('slide', 'VERB'), ('slide', 'NOUN'))],
#  [('its', 'PRON'),
#   (('building-products', 'ADV'), ('building-products', 'NOUN'))],
#  [('provide', 'VERB'), (('needed', 'VERB'), ('needed', 'ADJ'))],
#  [('$', '.'), (('107.03', 'ADV'), ('107.03', 'NUM'))],
#  [('*U*', 'X'), (('offering', 'VERB'), ('offering', 'NOUN'))],
#  [('be', 'VERB'), (('repriced', 'ADV'), ('repriced', 'VERB'))],
#  [('as', 'ADP'), (('cocky', 'ADV'), ('cocky', 'ADJ'))],
#  [('too', 'ADV'), (('yielding', 'VERB'), ('yielding', 'ADJ'))],
#  [('a', 'DET'), (('richer', 'ADV'), ('richer', 'ADJ'))],
#  [('the', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('profitable', 'ADJ'), (('pipe', 'ADV'), ('pipe', 'NOUN'))],
#  [('and', 'CONJ'), (('galvanized', 'ADV'), ('galvanized', 'ADJ'))],
#  [('galvanized', 'ADJ'), (('coated', 'ADV'), ('coated', 'VERB'))],
#  [('than', 'ADP'), (('lower-priced', 'ADV'), ('lower-priced', 'ADJ'))],
#  [('lower-priced', 'ADJ'), (('structural', 'ADV'), ('structural', 'ADJ'))],
#  [('excessively', 'ADV'), (('slashing', 'ADV'), ('slashing', 'VERB'))],
#  [('on', 'ADP'), (('semiconductors', 'ADV'), ('semiconductors', 'NOUN'))],
#  [('and', 'CONJ'), (('supercomputers', 'ADV'), ('supercomputers', 'NOUN'))],
#  [("n't", 'ADV'), (('forgotten', 'ADV'), ('forgotten', 'VERB'))],
#  [('the', 'DET'), (('leap', 'ADV'), ('leap', 'NOUN'))],
#  [('first', 'ADJ'), (('bout', 'ADV'), ('bout', 'NOUN'))],
#  [('of', 'ADP'), (('foreign-led', 'ADV'), ('foreign-led', 'ADJ'))],
#  [('last', 'ADJ'), (('half-hour', 'NOUN'), ('half-hour', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-254', 'ADV'), ('*T*-254', 'X'))],
#  [('written', 'VERB'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('prevent', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('of', 'ADP'), (('Child', 'ADV'), ('Child', 'NOUN'))],
#  [('He', 'PRON'), (('factors', 'NOUN'), ('factors', 'VERB'))],
#  [('factors', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('market', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('adjusted', 'VERB'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('eliminate', 'VERB'), (('266', 'ADV'), ('266', 'NUM'))],
#  [(',', '.'), (('176', 'ADV'), ('176', 'NUM'))],
#  [('best', 'ADJ'), (('known', 'ADJ'), ('known', 'VERB'))],
#  [('the', 'DET'), (('creator', 'ADV'), ('creator', 'NOUN'))],
#  [('team', 'NOUN'), (('car-development', 'ADV'), ('car-development', 'NOUN'))],
#  [('car-development', 'NOUN'), (('approach', 'VERB'), ('approach', 'NOUN'))],
#  [('approach', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('two', 'NUM'), (('midsized', 'ADJ'), ('midsized', 'VERB'))],
#  [('cars', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('maker', 'NOUN'), (('record', 'NOUN'), ('record', 'VERB'))],
#  [('to', 'PRT'), (('eclipse', 'ADV'), ('eclipse', 'VERB'))],
#  [('the', 'DET'), (('top-selling', 'ADV'), ('top-selling', 'ADJ'))],
#  [('The', 'DET'), (('percent', 'ADV'), ('percent', 'NOUN'))],
#  [('a', 'DET'), (('sprawling', 'ADV'), ('sprawling', 'ADJ'))],
#  [(',', '.'), (('balkanized', 'ADV'), ('balkanized', 'ADJ'))],
#  [('the', 'DET'), (('mammoth', 'ADV'), ('mammoth', 'ADJ'))],
#  [('which', 'DET'), (('flows', 'NOUN'), ('flows', 'VERB'))],
#  [('*T*-1', 'X'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('corn', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('obtained', 'VERB'), (('8300', 'NUM'), ('8300', 'ADJ'))],
#  [('are', 'VERB'), (('queuing', 'ADV'), ('queuing', 'VERB'))],
#  [('the', 'DET'), (('working', 'NOUN'), ('working', 'VERB'))],
#  [('very', 'ADV'), (('unsympathetic', 'ADV'), ('unsympathetic', 'ADJ'))],
#  [('bold', 'ADJ'), (('palace', 'ADV'), ('palace', 'NOUN'))],
#  [('palace', 'NOUN'), (('revolt', 'ADV'), ('revolt', 'NOUN'))],
#  [('to', 'PRT'), (('telephone', 'NOUN'), ('telephone', 'VERB'))],
#  [('them', 'PRON'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('to', 'PRT'), (('ban', 'NOUN'), ('ban', 'VERB'))],
#  [('have', 'VERB'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('GAF', 'NOUN'), (('TRIAL', 'ADV'), ('TRIAL', 'NOUN'))],
#  [('the', 'DET'), (('1990s', 'NUM'), ('1990s', 'NOUN'))],
#  [('into', 'ADP'), (('multinationals', 'ADV'), ('multinationals', 'NOUN'))],
#  [('gaining', 'VERB'), (('1,200', 'ADV'), ('1,200', 'NUM'))],
#  [('Jack', 'NOUN'), (('Mogavero', 'ADV'), ('Mogavero', 'NOUN'))],
#  [(',', '.'), (('Piscataway', 'ADV'), ('Piscataway', 'NOUN'))],
#  [(',', '.'), (('Wis.', 'ADV'), ('Wis.', 'NOUN'))],
#  [('$', '.'), (('4.5', 'ADV'), ('4.5', 'NUM'))],
#  [('is', 'VERB'), (('unworkable', 'ADV'), ('unworkable', 'ADJ'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('branch', 'NOUN'), (('unfunded', 'ADV'), ('unfunded', 'ADJ'))],
#  [('could', 'VERB'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('and', 'CONJ'), (('assert', 'ADV'), ('assert', 'VERB'))],
#  [('rider', 'NOUN'), (('restricting', 'ADV'), ('restricting', 'VERB'))],
#  [('to', 'PRT'), (('7.15', 'ADV'), ('7.15', 'NUM'))],
#  [('$', '.'), (('214', 'ADV'), ('214', 'NUM'))],
#  [('%', 'NOUN'), (('rise', 'VERB'), ('rise', 'NOUN'))],
#  [(',', '.'), (('reports', 'NOUN'), ('reports', 'VERB'))],
#  [('The', 'DET'), (('official', 'NOUN'), ('official', 'ADJ'))],
#  [('agency', 'NOUN'), (('PAP', 'ADV'), ('PAP', 'NOUN'))],
#  [('.', '.'), (('Bramalea', 'ADV'), ('Bramalea', 'NOUN'))],
#  [('GAF', 'NOUN'), (('trials', 'ADV'), ('trials', 'NOUN'))],
#  [('in', 'ADP'), (('mistrials', 'ADV'), ('mistrials', 'NOUN'))],
#  [('mistrials', 'NOUN'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('``', '.'), (('Funny', 'ADJ'), ('Funny', 'NOUN'))],
#  [('-LRB-', '.'), (('Soho', 'ADV'), ('Soho', 'NOUN'))],
#  [('anything', 'NOUN'), (('but', 'CONJ'), ('but', 'ADV'))],
#  [('The', 'DET'), (('turf', 'ADV'), ('turf', 'NOUN'))],
#  [('to', 'PRT'), (('Austria', 'ADV'), ('Austria', 'NOUN'))],
#  [('to', 'PRT'), (('Portugal', 'ADV'), ('Portugal', 'NOUN'))],
#  [('in', 'ADP'), (('Hammacher', 'ADV'), ('Hammacher', 'NOUN'))],
#  [('Hammacher', 'NOUN'), (('Schlemmer', 'ADV'), ('Schlemmer', 'NOUN'))],
#  [('a', 'DET'), (('fiber-optic', 'ADV'), ('fiber-optic', 'ADJ'))],
#  [('fiber-optic', 'ADJ'), (('Christmas', 'ADV'), ('Christmas', 'NOUN'))],
#  [('tree', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('string', 'ADV'), ('string', 'VERB'))],
#  [('two', 'NUM'), (('distorted', 'ADV'), ('distorted', 'ADJ'))],
#  [('unrecognizable', 'ADJ'), (('photos', 'ADV'), ('photos', 'NOUN'))],
#  [('Trump', 'NOUN'), (('withdrew', 'ADV'), ('withdrew', 'VERB'))],
#  [('$', '.'), (('120-a-share', 'ADV'), ('120-a-share', 'ADJ'))],
#  [('their', 'PRON'), (('wrath', 'ADV'), ('wrath', 'NOUN'))],
#  [('a', 'DET'), (('first-time', 'ADV'), ('first-time', 'ADJ'))],
#  [('program', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-99', 'ADV'), ('*T*-99', 'X'))],
#  [('have', 'VERB'), (('expunged', 'ADV'), ('expunged', 'VERB'))],
#  [('the', 'DET'), (('conviction', 'ADV'), ('conviction', 'NOUN'))],
#  [('of', 'ADP'), (('Orrick', 'ADV'), ('Orrick', 'NOUN'))],
#  [(',', '.'), (('Herrington', 'ADV'), ('Herrington', 'NOUN'))],
#  [('&', 'CONJ'), (('Sutcliffe', 'ADV'), ('Sutcliffe', 'NOUN'))],
#  [('out', 'PRT'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('much', 'ADV'), (('better', 'ADJ'), ('better', 'ADV'))],
#  [('men', 'NOUN'), (('exuded', 'ADV'), ('exuded', 'VERB'))],
#  [('is', 'VERB'), (('payable', 'ADV'), ('payable', 'ADJ'))],
#  [('payable', 'ADJ'), (('Jan.', 'ADV'), ('Jan.', 'NOUN'))],
#  [(',', '.'), (('aims', 'ADV'), ('aims', 'VERB'))],
#  [('a', 'DET'), (('sharper', 'ADV'), ('sharper', 'ADJ'))],
#  [('*U*', 'X'), (('decline', 'VERB'), ('decline', 'NOUN'))],
#  [('$', '.'), (('86.12', 'ADV'), ('86.12', 'NUM'))],
#  [("'s", 'PRT'), (('minicrash', 'ADV'), ('minicrash', 'NOUN'))],
#  [('been', 'VERB'), (('shaken', 'ADV'), ('shaken', 'VERB'))],
#  [('of', 'ADP'), (('resentment', 'ADV'), ('resentment', 'NOUN'))],
#  [(',', '.'), (('lightning-fast', 'ADV'), ('lightning-fast', 'ADJ'))],
#  [('lightning-fast', 'ADJ'), (('trades', 'VERB'), ('trades', 'NOUN'))],
#  [('futures', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('prices', 'NOUN'), (('reeling', 'ADV'), ('reeling', 'VERB'))],
#  [('``', '.'), (('Crime', 'ADV'), ('Crime', 'NOUN'))],
#  [('was', 'VERB'), (('awful', 'ADV'), ('awful', 'ADJ'))],
#  [('no', 'DET'), (('enrollment', 'ADV'), ('enrollment', 'NOUN'))],
#  [('in', 'ADP'), (('honors', 'ADV'), ('honors', 'NOUN'))],
#  [('*U*', 'X'), (('return', 'VERB'), ('return', 'NOUN'))],
#  [('``', '.'), (('ai', 'ADV'), ('ai', 'VERB'))],
#  [('in', 'ADP'), (('excess', 'ADJ'), ('excess', 'NOUN'))],
#  [('at', 'ADP'), (('7.79', 'ADV'), ('7.79', 'NUM'))],
#  [('at', 'ADP'), (('7.52', 'ADV'), ('7.52', 'NUM'))],
#  [('with', 'ADP'), (('7.60', 'ADV'), ('7.60', 'NUM'))],
#  [('The', 'DET'), (('school-board', 'ADV'), ('school-board', 'NOUN'))],
#  [('was', 'VERB'), (('crowded', 'ADV'), ('crowded', 'VERB'))],
#  [('who', 'PRON'), (('*T*-98', 'ADV'), ('*T*-98', 'X'))],
#  [('to', 'PRT'), (('testify', 'ADV'), ('testify', 'VERB'))],
#  [('market', 'NOUN'), (('overvalued', 'ADV'), ('overvalued', 'VERB'))],
#  [('.', '.'), (('Outside', 'ADV'), ('Outside', 'ADJ'))],
#  [('young', 'ADJ'), (('pressman', 'ADV'), ('pressman', 'NOUN'))],
#  [('pressman', 'NOUN'), (('filling', 'NOUN'), ('filling', 'VERB'))],
#  [('edition', 'NOUN'), (('headlined', 'ADV'), ('headlined', 'VERB'))],
#  [('Examiner', 'NOUN'), (('Closes', 'ADV'), ('Closes', 'VERB'))],
#  [('*-1', 'X'), (('needing', 'ADV'), ('needing', 'VERB'))],
#  [('A', 'DET'), (('high-balance', 'ADV'), ('high-balance', 'ADJ'))],
#  [('banks', 'NOUN'), (('pine', 'ADV'), ('pine', 'VERB'))],
#  [('pine', 'VERB'), (('for', 'ADP'), ('for', 'PRT'))],
#  [('give', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('thought', 'VERB'), ('thought', 'NOUN'))],
#  [('might', 'VERB'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [('expensive', 'ADJ'), (('cleanup', 'ADV'), ('cleanup', 'NOUN'))],
#  [('or', 'CONJ'), (('burn', 'ADV'), ('burn', 'VERB'))],
#  [('burn', 'VERB'), (('cleaner-burning', 'ADV'), ('cleaner-burning', 'ADJ'))],
#  [('cleaner-burning', 'ADJ'), (('fuels', 'ADV'), ('fuels', 'NOUN'))],
#  [('which', 'DET'), (('*T*-116', 'ADV'), ('*T*-116', 'X'))],
#  [('jumped', 'VERB'), (('3.23', 'ADV'), ('3.23', 'NUM'))],
#  [('to', 'PRT'), (('436.01', 'ADV'), ('436.01', 'NUM'))],
#  [('be', 'VERB'), (('no', 'DET'), ('no', 'ADV'))],
#  [(',', '.'), (('Phoenix', 'ADV'), ('Phoenix', 'NOUN'))],
#  [('turned', 'VERB'), (('thumbs', 'ADV'), ('thumbs', 'NOUN'))],
#  [('thumbs', 'NOUN'), (('down', 'ADV'), ('down', 'PRT'))],
#  [('it', 'PRON'), (('bid', 'NOUN'), ('bid', 'VERB'))],
#  [('to', 'PRT'), (('design', 'NOUN'), ('design', 'VERB'))],
#  [('the', 'DET'), (('Saitama', 'ADV'), ('Saitama', 'NOUN'))],
#  [('Saitama', 'NOUN'), (('prefectural', 'ADV'), ('prefectural', 'ADJ'))],
#  [('years', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('it', 'PRON'), (('bid', 'NOUN'), ('bid', 'VERB'))],
#  [('to', 'PRT'), (('plan', 'NOUN'), ('plan', 'VERB'))],
#  [('for', 'ADP'), (('Wakayama', 'ADV'), ('Wakayama', 'NOUN'))],
#  [('how', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('more', 'ADV'), (('scarce', 'ADV'), ('scarce', 'ADJ'))],
#  [('to', 'PRT'), (('falsify', 'ADV'), ('falsify', 'VERB'))],
#  [('.', '.'), (('Proceeds', 'ADV'), ('Proceeds', 'NOUN'))],
#  [('buy', 'VERB'), (('back', 'ADV'), ('back', 'PRT'))],
#  [('they', 'PRON'), (('test-drive', 'ADV'), ('test-drive', 'VERB'))],
#  [('an', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('Express', 'NOUN'), (('calculator', 'ADV'), ('calculator', 'NOUN'))],
#  [('continually', 'ADV'), (('advise', 'ADV'), ('advise', 'VERB'))],
#  [('``', '.'), (('Wa', '.'), ('Wa', 'NOUN'))],
#  [('is', 'VERB'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('*EXP*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('.', '.'), (('Groups', 'ADV'), ('Groups', 'NOUN'))],
#  [('*', 'X'), (('advocating', 'ADV'), ('advocating', 'VERB'))],
#  [('policies', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('ignoring', 'VERB'),
#   (('discrimination', 'ADV'), ('discrimination', 'NOUN'))],
#  [('D.', 'NOUN'), (('Carney', 'ADV'), ('Carney', 'NOUN'))],
#  [('$', '.'), (('777', 'ADV'), ('777', 'NUM'))],
#  [('0', 'X'), (('early', 'ADV'), ('early', 'ADJ'))],
#  [('became', 'VERB'), (('impatient', 'ADV'), ('impatient', 'NOUN'))],
#  [('for', 'ADP'), (('supercomputers', 'ADV'), ('supercomputers', 'NOUN'))],
#  [('court', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('Charles', 'NOUN'), (('Wohlstetter', 'ADV'), ('Wohlstetter', 'NOUN'))],
#  [('is', 'VERB'), (('rallying', 'ADV'), ('rallying', 'VERB'))],
#  [('the', 'DET'), (('anti-program', 'ADV'), ('anti-program', 'ADJ'))],
#  [('anti-program', 'ADJ'), (('trading', 'VERB'), ('trading', 'NOUN'))],
#  [('trading', 'NOUN'), (('cause', 'VERB'), ('cause', 'NOUN'))],
#  [('``', '.'), (('countless', 'ADV'), ('countless', 'ADJ'))],
#  [('letters', 'NOUN'), (('offering', 'NOUN'), ('offering', 'VERB'))],
#  [('offering', 'VERB'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('.', '.'), (('LSI', 'ADV'), ('LSI', 'NOUN'))],
#  [('LSI', 'NOUN'), (('Logic', 'ADV'), ('Logic', 'NOUN'))],
#  [('*U*', 'X'), (('third-quarter', 'NOUN'), ('third-quarter', 'ADJ'))],
#  [('third-quarter', 'ADJ'), (('net', 'NOUN'), ('net', 'ADJ'))],
#  [('charge', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-145', 'ADV'), ('*T*-145', 'X'))],
#  [('continuing', 'VERB'),
#   (('industry-wide', 'ADV'), ('industry-wide', 'ADJ'))],
#  [('in', 'ADP'), (('semiconductor', 'ADV'), ('semiconductor', 'NOUN'))],
#  [('it', 'PRON'), (('emerges', 'ADV'), ('emerges', 'VERB'))],
#  [('be', 'VERB'), (('worth', 'ADP'), ('worth', 'ADJ'))],
#  [('worth', 'ADJ'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('broken', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('.', '.'), (('DISCOUNT', 'ADV'), ('DISCOUNT', 'NOUN'))],
#  [('The', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('crops', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('I', 'PRON'), (('tell', 'ADV'), ('tell', 'VERB'))],
#  [('need', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('Cosby', 'NOUN'), (("'", 'PRT'), ("'", '.'))],
#  [('Once', 'ADV'), (('there', 'DET'), ('there', 'ADV'))],
#  [(',', '.'), (('what', 'PRON'), ('what', 'DET'))],
#  [('of', 'ADP'), (('escape', 'ADV'), ('escape', 'NOUN'))],
#  [('*T*-1', 'X'), (('open', 'VERB'), ('open', 'ADJ'))],
#  [('than', 'ADP'), (('drink', 'VERB'), ('drink', 'NOUN'))],
#  [('or', 'CONJ'), (('insanity', 'ADV'), ('insanity', 'NOUN'))],
#  [('to', 'PRT'), (('phase', 'ADV'), ('phase', 'VERB'))],
#  [('phase', 'VERB'), (('out', 'ADP'), ('out', 'PRT'))],
#  [('make', 'VERB'), (('appropriate', 'ADV'), ('appropriate', 'ADJ'))],
#  [("'s", 'PRT'), (('borrowing', 'VERB'), ('borrowing', 'NOUN'))],
#  [('$', '.'), (('2.80', 'ADV'), ('2.80', 'NUM'))],
#  [(',', '.'), (('dominates', 'ADV'), ('dominates', 'VERB'))],
#  [('on', 'ADP'), (('Novell', 'ADV'), ('Novell', 'NOUN'))],
#  [("'s", 'PRT'), (('NetWare', 'ADV'), ('NetWare', 'NOUN'))],
#  [('network', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('been', 'VERB'), (('notified', 'ADV'), ('notified', 'VERB'))],
#  [('drawn', 'VERB'), (('*-139', 'ADV'), ('*-139', 'X'))],
#  [('that', 'DET'), (('fuller', 'ADV'), ('fuller', 'ADJ'))],
#  [('you', 'PRON'), (('bothered', 'ADV'), ('bothered', 'VERB'))],
#  [('the', 'DET'), (('inverse', 'ADV'), ('inverse', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('some', 'DET'), (('degree', 'ADV'), ('degree', 'NOUN'))],
#  [('with', 'ADP'), (('Premier', 'ADV'), ('Premier', 'NOUN'))],
#  [('Li', 'NOUN'), (('Peng', 'ADV'), ('Peng', 'NOUN'))],
#  [('he', 'PRON'), (('hoped', 'ADV'), ('hoped', 'VERB'))],
#  [("n't", 'ADV'), (('encounter', 'ADV'), ('encounter', 'VERB'))],
#  [('machine', 'NOUN'), (('guns', 'ADV'), ('guns', 'NOUN'))],
#  [('one', 'NUM'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('each', 'DET'), (('105', 'ADV'), ('105', 'NUM'))],
#  [('The', 'DET'), (('Chinese', 'ADJ'), ('Chinese', 'NOUN'))],
#  [('took', 'VERB'), (('aim', 'VERB'), ('aim', 'NOUN'))],
#  [('.', '.'), (('Odyssey', 'ADV'), ('Odyssey', 'NOUN'))],
#  [('provision', 'NOUN'), (('amounts', 'NOUN'), ('amounts', 'VERB'))],
#  [('a', 'DET'), (('one-house', 'ADV'), ('one-house', 'ADJ'))],
#  [('neither', 'DET'), (('bicameral', 'ADV'), ('bicameral', 'ADJ'))],
#  [('nor', 'CONJ'), (('presentation', 'ADV'), ('presentation', 'NOUN'))],
#  [('his', 'PRON'), (('signature', 'ADV'), ('signature', 'NOUN'))],
#  [('and', 'CONJ'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('possible', 'ADJ'), (('repayment', 'ADV'), ('repayment', 'NOUN'))],
#  [('in', 'ADP'), (('pre-Communist', 'ADV'), ('pre-Communist', 'ADJ'))],
#  [('pre-Communist', 'ADJ'), (('Russian', 'ADV'), ('Russian', 'ADJ'))],
#  [('death', 'NOUN'), (('knell', 'ADV'), ('knell', 'NOUN'))],
#  [('made', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('that', 'ADP'), (('only', 'ADJ'), ('only', 'ADV'))],
#  [('the', 'DET'), (('homeless', 'ADJ'), ('homeless', 'NOUN'))],
#  [('homeless', 'NOUN'), (('exhibits', 'ADV'), ('exhibits', 'VERB'))],
#  [('$', '.'), (('1.1650', 'ADV'), ('1.1650', 'NUM'))],
#  [('shut', 'VERB'), (('down', 'ADV'), ('down', 'PRT'))],
#  [('A', 'DET'),
#   (('telephone-information', 'ADV'), ('telephone-information', 'NOUN'))],
#  [('The', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('Japanese', 'NOUN'), (('retort', 'ADV'), ('retort', 'NOUN'))],
#  [('make', 'VERB'), (('concessions', 'ADV'), ('concessions', 'NOUN'))],
#  [('``', '.'), (('genuine', 'ADV'), ('genuine', 'ADJ'))],
#  [('this', 'DET'), (('touchy', 'ADV'), ('touchy', 'ADJ'))],
#  [('touchy', 'ADJ'), (('issue', 'VERB'), ('issue', 'NOUN'))],
#  [('to', 'PRT'), (('enact', 'ADV'), ('enact', 'VERB'))],
#  [('law', 'NOUN'), (('compatible', 'ADV'), ('compatible', 'ADJ'))],
#  [('software', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('to', 'PRT'), (('literary', 'ADV'), ('literary', 'ADJ'))],
#  [('literary', 'ADJ'), (('works', 'VERB'), ('works', 'NOUN'))],
#  [('and', 'CONJ'), (('amortization', 'ADV'), ('amortization', 'NOUN'))],
#  [('picture', 'NOUN'), (('tubes', 'ADV'), ('tubes', 'NOUN'))],
#  [(',', '.'), (('assemble', 'ADV'), ('assemble', 'VERB'))],
#  [('and', 'CONJ'), (('export', 'NOUN'), ('export', 'VERB'))],
#  [('.', '.'), (('Characters', 'ADV'), ('Characters', 'NOUN'))],
#  [('drink', 'VERB'), (('Salty', 'ADV'), ('Salty', 'NOUN'))],
#  [('Salty', 'NOUN'), (('Dogs', 'ADV'), ('Dogs', 'NOUN'))],
#  [(',', '.'), (('whistle', 'ADV'), ('whistle', 'VERB'))],
#  [('``', '.'), (('Johnny', 'ADV'), ('Johnny', 'NOUN'))],
#  [('B.', 'NOUN'), (('Goode', 'ADV'), ('Goode', 'NOUN'))],
#  [('watch', 'VERB'), (('Bugs', 'ADV'), ('Bugs', 'NOUN'))],
#  [('Bugs', 'NOUN'), (('Bunny', 'ADV'), ('Bunny', 'NOUN'))],
#  [('made', 'VERB'), (('clear', 'ADJ'), ('clear', 'ADV'))],
#  [('an', 'DET'), (('unofficial', 'ADV'), ('unofficial', 'ADJ'))],
#  [('unofficial', 'ADJ'), (('envoy', 'ADV'), ('envoy', 'NOUN'))],
#  [('``', '.'), (('headed', 'ADV'), ('headed', 'VERB'))],
#  [("n't", 'ADV'), (('curbed', 'ADV'), ('curbed', 'VERB'))],
#  [('Poland', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('b', 'ADV'), ('b', 'X'))],
#  [('the', 'DET'), (('busiest', 'ADV'), ('busiest', 'ADJ'))],
#  [('year', 'NOUN'), (('so', 'ADP'), ('so', 'ADV'))],
#  [('so', 'ADV'), (('far', 'ADV'), ('far', 'ADJ'))],
#  [('volume', 'NOUN'), (('averaged', 'ADV'), ('averaged', 'VERB'))],
#  [('many', 'ADJ'), (('academics', 'ADV'), ('academics', 'NOUN'))],
#  [('the', 'DET'), (('middle', 'ADJ'), ('middle', 'NOUN'))],
#  [('the', 'DET'), (('evil', 'ADJ'), ('evil', 'NOUN'))],
#  [('driving', 'VERB'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('will', 'VERB'), (('climb', 'ADV'), ('climb', 'VERB'))],
#  [('from', 'ADP'), (('566.54', 'ADV'), ('566.54', 'NUM'))],
#  [('from', 'ADP'), (('28.53', 'ADV'), ('28.53', 'NUM'))],
#  [('The', 'DET'), (('senior', 'ADJ'), ('senior', 'NOUN'))],
#  [('is', 'VERB'), (('Nigel', 'ADV'), ('Nigel', 'NOUN'))],
#  [('Nigel', 'NOUN'), (('Judah', 'ADV'), ('Judah', 'NOUN'))],
#  [('nations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-7', 'ADV'), ('*T*-7', 'X'))],
#  [('higher', 'ADJ'), (('standard', 'ADJ'), ('standard', 'NOUN'))],
#  [('the', 'DET'), (('smooth', 'ADV'), ('smooth', 'ADJ'))],
#  [(',', '.'), (('needle-like', 'ADV'), ('needle-like', 'ADJ'))],
#  [('crocidolite', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('are', 'VERB'), (('classified', 'ADV'), ('classified', 'VERB'))],
#  [('as', 'ADP'), (('amphobiles', 'ADV'), ('amphobiles', 'NOUN'))],
#  [('to', 'PRT'), (('Brooke', 'ADV'), ('Brooke', 'NOUN'))],
#  [('of', 'ADP'), (('pathlogy', 'ADV'), ('pathlogy', 'NOUN'))],
#  [('of', 'ADP'), (('Vermont', 'ADV'), ('Vermont', 'NOUN'))],
#  [('them', 'PRON'), (('fearful', 'ADV'), ('fearful', 'ADJ'))],
#  [('economic', 'ADJ'), (('hegemony', 'ADV'), ('hegemony', 'NOUN'))],
#  [('bonds', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('really', 'ADV'), (('battered', 'ADV'), ('battered', 'VERB'))],
#  [('.', '.'), (('Declining', 'ADV'), ('Declining', 'VERB'))],
#  [('slightly', 'ADV'), (('outnumbered', 'ADV'), ('outnumbered', 'VERB'))],
#  [(',', '.'), (('454', 'ADV'), ('454', 'NUM'))],
#  [('to', 'PRT'), (('451', 'ADV'), ('451', 'NUM'))],
#  [('Washington', 'NOUN'), (('Post', 'ADV'), ('Post', 'NOUN'))],
#  [('issue', 'NOUN'), (('trades', 'NOUN'), ('trades', 'VERB'))],
#  [('its', 'PRON'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('such', 'ADJ'), (('variables', 'ADV'), ('variables', 'NOUN'))],
#  [('Peter', 'NOUN'), (('Marcus', 'ADV'), ('Marcus', 'NOUN'))],
#  [('the', 'DET'), (('appliance', 'ADV'), ('appliance', 'NOUN'))],
#  [('.', '.'), (('Ruth', 'ADV'), ('Ruth', 'NOUN'))],
#  [('Nelson', 'NOUN'), (('Cullowhee', 'ADV'), ('Cullowhee', 'NOUN'))],
#  [('Its', 'PRON'), (('entrenched', 'ADV'), ('entrenched', 'VERB'))],
#  [('fighting', 'VERB'), (('tooth', 'ADV'), ('tooth', 'NOUN'))],
#  [('and', 'CONJ'), (('nail', 'ADV'), ('nail', 'NOUN'))],
#  [('*', 'X'), (('Related', 'ADV'), ('Related', 'VERB'))],
#  [('was', 'VERB'), (('converting', 'ADV'), ('converting', 'VERB'))],
#  [('Santa', 'NOUN'), (('Clara', 'ADV'), ('Clara', 'NOUN'))],
#  [('.', '.'), (('Wellcome', 'ADV'), ('Wellcome', 'NOUN'))],
#  [('to', 'PRT'), (('666', 'ADV'), ('666', 'NUM'))],
#  [('an', 'DET'), (('arbitrager', 'ADV'), ('arbitrager', 'NOUN'))],
#  [('.', '.'), (('Most', 'ADJ'), ('Most', 'ADV'))],
#  [('and', 'CONJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('at', 'ADP'), (('879', 'ADV'), ('879', 'NUM'))],
#  [('$', '.'), (('13.90', 'ADV'), ('13.90', 'NUM'))],
#  [('building', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('company', 'NOUN'), (('while', 'ADP'), ('while', 'NOUN'))],
#  [('*-1', 'X'), (('refocusing', 'ADV'), ('refocusing', 'NOUN'))],
#  [('refocusing', 'NOUN'), (('building', 'VERB'), ('building', 'NOUN'))],
#  [('and', 'CONJ'), (('remodeling', 'ADV'), ('remodeling', 'NOUN'))],
#  [('Some', 'DET'), (('long-tenured', 'ADV'), ('long-tenured', 'ADJ'))],
#  [('effective', 'ADJ'),
#   (('search-and-seizure', 'ADV'), ('search-and-seizure', 'ADJ'))],
#  [('to', 'PRT'), (('aid', 'NOUN'), ('aid', 'VERB'))],
#  [('David', 'NOUN'), (('Schmidt', 'ADV'), ('Schmidt', 'NOUN'))],
#  [('``', '.'), (('Citizen', 'ADV'), ('Citizen', 'NOUN'))],
#  [('*T*-1', 'X'), (('causes', 'NOUN'), ('causes', 'VERB'))],
#  [('investors', 'NOUN'), (('initiating', 'ADV'), ('initiating', 'VERB'))],
#  [('a', 'DET'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('or', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('purchase', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))]]

# %% [markdown]
# ##### Before proceeding for dealing with unknown words, lets first see how many unknown words we have. Unknows words would be
# ##### those words that are present in the test set but not in the train set. That is the words the algorithm has not seen before.

# %%
# Unknown words 

test_vocabulary_set = set([t for t in test_tagged_words])

unknown_words = list(test_vocabulary_set - training_vocabulary_set)
print("Total Unknown words :", len(unknown_words))
print("\n")
print("Unknown Words :", unknown_words)
# Out:
# Total Unknown words : 304
#
#
# Unknown Words : ['7.15', '214', 'pressman', 'Premier', 'vinyl', 'mobster', 'erudite', 'scarce', 'ritual', 'first-time', 'outnumbered', 'richer', 'Brooke', 'prefectural', 'percent', '*T*-226', 'discrimination', 'slashing', 'photos', 'bout', 'semiconductor', 'intricate', 'Berger', 'busiest', 'emerges', 'Piscataway', 'lower-priced', 'thumbs', 'Declining', 'leasing', 'anti-program', 'Crime', 'DISCOUNT', 'burn', 'disaffected', 'sheep', 'leap', 'high-balance', 'industry-wide', 'fiber-optic', 'advise', 'checkbook', 'enact', 'conviction', '*-134', 'payable', 'tooth', 'whistle', 'retort', 'appropriate', 'Dogs', 'distorted', 'envoy', '3,600', 'Bramalea', 'galvanized', 'layer', '1,200', 'pre-Communist', 'string', 'Close', 'knell', 'coated', 'hegemony', 'remodeling', 'smooth', 'Huppert', 'search-and-seizure', 'Proceeds', 'Clara', 'semiconductors', '*T*-98', 'presentation', 'structural', '266', 'cocky', 'sinister', '28.53', 'Groups', 'foreign-led', '7.52', 'shaken', 'inherited', 'unrealistically', 'aims', 'Frances', 'skyward', 'Citizen', '107.03', 'municipality', 'H.N.', 'Cullowhee', 'pipe', 'Soho', 'fearful', 'Orrick', 'Andean', 'overvalued', '120-a-share', '454', 'encounter', 'eclipse', 'reeling', 'Closes', 'sprawling', 'nearly-30', 'Related', 'behest', 'queuing', 'falsify', 'countless', 'hoped', 'Goode', 'pathlogy', 'Johns', 'Outside', 'economical', 'Schmidt', 'balkanized', 'solemn', 'catch-up', 'third-largest', 'sharper', 'CEO', 'rallying', 'insanity', 'calculator', '7.60', 'Hopkins', 'Ruth', 'one-house', 'Portugal', 'concessions', 'inverse', '*T*-145', 'averaged', 'touchy', 'intoxication', 'serviced', 'fuels', '436.01', 'needle-like', 'wrath', 'Wellcome', 'Peng', 'lightning-fast', 'Wis.', 'unofficial', 'curbed', 'unworkable', 'tubes', 'resentment', '*-139', 'test-drive', 'needing', 'compatible', 'cleaner-burning', 'thin-lipped', 'Bunny', 'presumably', 'Christmas', 'Judah', 'Hamilton', 'building-products', 'palace', 'Mogavero', 'revolt', 'school-board', 'Herrington', 'maybe', '4.5', 'succession', 'Johnny', 'Austria', 'long-tenured', '3.23', 'pine', 'converting', 'hard-drinking', 'escape', 'Sutcliffe', '*T*-218', 'Hammacher', 'Billings', 'bothered', 'search', 'exhibits', 'exuded', 'notified', 'exclusively', '7.79', 'Breakey', 'Odyssey', 'minicrash', 'Characters', 'excessively', 'unfunded', '3.80', '105', 'Wohlstetter', 'supercomputers', 'Schlemmer', 'Salty', 'mammoth', 'appliance', 'Bermuda-based', 'amortization', 'Nigel', 'dominates', '777', 'assert', '*T*-254', '176', 'nail', 'turf', 'multinationals', 'withdrew', 'fifth-largest', 'advocating', 'arbitrager', 'guns', 'ai', 'Post', 'top-selling', 'car-development', 'cleanup', '2.80', '*T*-99', 'Bugs', 'Carney', 'phase', 'b', 'elusive', 'tell', 'refocusing', 'genuine', 'entrenched', '86.12', 'PAP', '879', 'trafficking', 'literary', 'telephone-information', 'enrollment', 'amphobiles', 'variables', 'Logic', 'headlined', 'Russian', '1.1650', 'faultlessly', 'repayment', 'Jan.', 'restricting', 'forgotten', '566.54', 'mistrials', 'creator', 'climb', 'impatient', 'assemble', 'initiating', 'expunged', 'awful', 'unsympathetic', 'filled', 'battered', 'committees', 'honors', 'NetWare', 'LSI', 'Vermont', 'crowded', '451', 'classified', 'headed', 'Marie', 'testify', 'Isabelle', 'signature', 'Marcus', 'degree', '*T*-116', 'TRIAL', 'trials', 'Novell', '*T*-7', 'Phoenix', 'Child', 'Altogether', '13.90', '*T*-155', 'academics', 'Psychiatry', 'recession-inspired', 'Fischer', 'Saitama', 'snow', '666', 'bicameral', '38.3', 'Wakayama', 'fuller', 'repriced']

# %% [markdown]
# # Method 1
#
# The default Vanilla viterbi algorithm achieved an accuracy of about 90.7%. This approx. 9% loss of accuracy was majorly due to the fact that when the algorithm encountered an unknown word (i.e. not present in the training set, such as 'Twitter'), it assigned an incorrect tag arbitrarily. This is because, for unknown words, the emission probabilities for all candidate tags are 0, so the algorithm arbitrarily chooses (the first) tag.
#
# Now lets see how we can minimize this loss by modifying the vanilla viterbi.
#
# If a word is not present in the training vocabulary (unknown word), its emission probability will be **ZERO**. In that case the state probability will inturn be zero. Thus in cases where the algorithm encounters a word which it has not see previously, we can omit the emission probability and only consider the transition probability.
#
# The algorithm can be modified to deal the case as below -
#
#
# **If word in unknown then
# consider only the transition_p (emission probability being 0)
# else
#    consider both the emission and transition probability.**

# %%
# Modified Viterbi Heuristic
def Vanilla_Viterbi_for_Unknown_Words(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            
            # modification to the original vanilla viterbi algorithm 
            # to consider unknown words
            if word not in training_vocabulary_set:
                state_probability = transition_p
            else:
                state_probability = emission_p * transition_p
                
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
# tagging the test sentences
unknown_word_tagged_seq = Vanilla_Viterbi_for_Unknown_Words(test_tagged_words)

# accuracy
unknown_word_check = [i for i, j in zip(unknown_word_tagged_seq, test_run_base) if i == j]

optimized_viterbi_accuracy = len(unknown_word_check)/len(unknown_word_tagged_seq)

print("The accuracy of the Vanilla Viterbi Algorithm after modification to handle unknown words is -", optimized_viterbi_accuracy)
# Out:
# The accuracy of the Vanilla Viterbi Algorithm after modification to handle unknown words is - 0.9316115702479338

# %% [markdown]
# We see the modified viterbi algorithm **performs better** than the original vanilla viterbi algorithm. The modified viterbi achieves an accuracy of (approx.) **93.16** comapred to **90.7%** of the vanilla viterbi.
#
# Still there is a loss of approx. 7%.
#
# Now lets see if we can in reduce this loss further.
#
# ### Let's try with some Lexicon and Rule-Based Models for POS Tagging.
#
# #### Unigram Tagger

# %%
# Unigram Tagger

unigram_tagger = nltk.UnigramTagger(train_set)
unigram_tagger_accuracy = unigram_tagger.evaluate(test_set)
print("The accuracy of the Unigram Tagger is -", unigram_tagger_accuracy)
# Out:
# The accuracy of the Unigram Tagger is - 0.9028925619834711

# %% [markdown]
# ##### Let's now try combining the unigram tagger with a rule based regex tagger.

# %%
# patterns for tagging using a rule based regex tagger -

patterns = [
    (r'^[aA-zZ].*[0-9]+','NOUN'),  # Alpha Numeric
    (r'.*ness$', 'NOUN'),
    (r'.*\'s$', 'NOUN'),              # possessive nouns
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'.*', 'NOUN'),    
    (r'.*ly$', 'ADV'),
    (r'^(0|([*|-|$].*))','X'), # Any special character combination
    (r'.*ould$', 'X'), # modals
    (r'(The|the|A|a|An|an)$', 'DET'),
    (r'^([0-9]|[aA-zZ])+\-[aA-zZ]*$','ADJ'),
    (r'.*able$', 'ADJ'), # adjective like 100-megabytes 237-Seats
    (r'[aA-zZ]+(ed|ing|es)$', 'VERB'), # Any word ending with 'ing' or 'ed' is a verb
    (r'[0-9].?[,\/]?[0-9]*','NUM')# Numbers 
    ]

# %%
# rule based RegexpTagger

rule_based_tagger = nltk.RegexpTagger(patterns)

# unigram tagger backed up by the rule-based tagger
rule_based_unigram_tagger = nltk.UnigramTagger(train_set, backoff = rule_based_tagger)

accuracy_rule_based_unigram_tagger = rule_based_unigram_tagger.evaluate(test_set)

print("The accuracy of the Unigram Tagger backed up by the RegexpTagger is -", accuracy_rule_based_unigram_tagger)
# Out:
# The accuracy of the Unigram Tagger backed up by the RegexpTagger is - 0.9320247933884298

# %%
# Bigram tagger

bigram_tagger = nltk.BigramTagger(train_set, backoff = rule_based_unigram_tagger)
bigram_tagger.evaluate(test_set)
accuracy_bigram_tagger = bigram_tagger.evaluate(test_set)
print("The accuracy of the Bigram Tagger backed up by the rule_based_unigram_tagger is -", accuracy_bigram_tagger)
# Out:
# The accuracy of the Bigram Tagger backed up by the rule_based_unigram_tagger is - 0.9398760330578513

# %%
# trigram tagger

trigram_tagger = nltk.TrigramTagger(train_set, backoff = bigram_tagger)
trigram_tagger.evaluate(test_set)
accuracy_trigram_tagger = trigram_tagger.evaluate(test_set)
print("The accuracy of the Trigram Tagger backed up by the bigram_tagger is -", accuracy_trigram_tagger)
# Out:
# The accuracy of the Trigram Tagger backed up by the bigram_tagger is - 0.9409090909090909

# %% [markdown]
# # Method 2
#
# We see that the Trigram Tagger backed up by the bigram tagger gives an accuracy of about 94.1%. Let's now try to modify the viterbi algorithm to use this trigram tagger as a back-off.
#
# When the viterbi algorithm is not able to tag an unknown word, it uses the rule-based tagger.

# %%
# A trigram tagger backed off by a rule based tagger.

def trigram_tagger(word, train_set = train_set):
    
    patterns = [
    (r'[aA-zZ]+(ed|ing|es)$', 'VERB'), # Any word ending with 'ing' or 'ed' is a verb

    (r'.*ly$', 'ADV'),
        
    (r'^([0-9]|[aA-zZ])+\-[aA-zZ]*$','ADJ'),
    (r'.*able$', 'ADJ'), 
    (r'.*ful$', 'ADJ'),
    (r'.*ous$', 'ADJ'),
        
    (r'^[aA-zZ].*[0-9]+','NOUN'),     # Alpha Numeric
    (r'.*ness$', 'NOUN'),
    (r'.*\'s$', 'NOUN'),              # possessive nouns - words ending with 's
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'.*ers$', 'NOUN'),              # eg.- kinderganteners, autobioghapgers
    (r'.*ment$', 'NOUN'),
    (r'.*town$', 'NOUN'),
        
    (r'^(0|([*|-|$].*))','X'), # Any special character combination
    (r'.*ould$', 'X'),
        
    (r'(The|the|A|a|An|an|That|that|This|this|Those|those|These|these)$', 'DET'), # That/this/these/those belong to the category of Demonstrative determiners
    (r'[0-9].?[,\/]?[0-9]*','NUM'), # Numbers 
        
    (r'.*', 'NOUN')
    ]

    regex_based_tagger = nltk.RegexpTagger(patterns)

    # trigram backed up by the regex tagger
    trigram_regex_tagger = nltk.TrigramTagger(train_set, backoff = regex_based_tagger)
    return trigram_regex_tagger.tag_sents([[(word)]])

# %%
def viterbi_backedup_by_trigram_tagger(words, train_bag = train_tagged_words):
    state = []
    tag_set = list(set([pair[1] for pair in train_bag]))
    
    # use the trigram tagger backed up by the rule based tagger
    # for unknown words.
    for key, word in enumerate(words):
        if word not in training_vocabulary_set:
            unknown_word_tag = trigram_tagger(word)
            for sent in unknown_word_tag:
                for tup in sent:
                    state.append(tup[1])
        else:            
            p = [] 
            for tag in tag_set:
                if key == 0:
                    transition_p = tags_df.loc['.', tag]
                else:
                    transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
                emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
                state_probability = emission_p * transition_p    
                p.append(state_probability)
            
            pmax = max(p)
            # getting state for which probability is maximum
            state_max = tag_set[p.index(pmax)] 
            state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# # Evaluating tagging accuracy

# %%
# tagging the test sentences
viterbi_trigram_tagged_seq = viterbi_backedup_by_trigram_tagger(test_tagged_words)

# accuracy
viterbi_trigram_word_check = [i for i, j in zip(viterbi_trigram_tagged_seq, test_run_base) if i == j]

viterbi_trigram_accuracy = len(viterbi_trigram_word_check)/len(viterbi_trigram_tagged_seq)

print("The accuracy of the viterbi_backedup_by_trigram_tagger is -", viterbi_trigram_accuracy)
# Out:
# The accuracy of the viterbi_backedup_by_trigram_tagger is - 0.9553719008264463

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm
#
# ### 1. First lets check the tagging accuracy on the test_set data generated using the test_train_split

# %%
acccuracy_data = [['Vanilla Viterbi', vanilla_viterbi_accuracy*100], 
                  ['Optimized Vanilla Viterbi', optimized_viterbi_accuracy*100], 
                  ['Unigram Tagger', unigram_tagger_accuracy*100],
                  ['Unigram + RegexpTagger', accuracy_rule_based_unigram_tagger*100],
                  ['Bigram Tagger + Unigram_tagger', accuracy_bigram_tagger*100],
                  ['Trigram Tagger + Bigram_tagger', accuracy_trigram_tagger*100],
                  ['Viterbi + Trigram_tagger', viterbi_trigram_accuracy*100]]

acccuracy_data_df = pd.DataFrame(acccuracy_data, columns = ['Tagging_Algorithm', 'Tagging_Accuracy'])

acccuracy_data_df.set_index('Tagging_Algorithm', drop = True, inplace = True)

acccuracy_data_df
# Out:
#                                 Tagging_Accuracy
# Tagging_Algorithm
# Vanilla Viterbi                        90.764463
# Optimized Vanilla Viterbi              93.161157
# Unigram Tagger                         90.289256
# Unigram + RegexpTagger                 93.202479
# Bigram Tagger + Unigram_tagger         93.987603
# Trigram Tagger + Bigram_tagger         94.090909
# Viterbi + Trigram_tagger               95.537190

# %%
acccuracy_data_df.plot.line(rot = 90, legend = False)

# %% [markdown]
# ### 2.  Next, lets check the tagging accuracies for the algorithm on the sample test sentences provided -

# %%
sample_test_sentences = ['Android is a mobile operating system developed by Google.',
"Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.",
"Google and Twitter made a deal in 2015 that gave Google access to Twitter's firehose.",
"Twitter is an online news and social networking service on which users post and interact with messages known as tweets.",
"Before entering politics, Donald Trump was a domineering businessman and a television personality.",
"The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years.",
"This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe.",
"Show me the cheapest round trips from Dallas to Atlanta",
"I would like to see flights from Denver to Philadelphia.",
"Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.",
"NASA invited social media users to experience the launch of ICESAT-2 Satellite."]

# %%
sample_test_tokenized_sents = [word_tokenize(sent) for sent in sample_test_sentences]
sample_test_corpus_pos_tags = nltk.pos_tag_sents(sample_test_tokenized_sents, tagset = 'universal')
sample_test_corpus_pos_tags
# Out:
# [[('Android', 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('mobile', 'ADJ'),
#   ('operating', 'NOUN'),
#   ('system', 'NOUN'),
#   ('developed', 'VERB'),
#   ('by', 'ADP'),
#   ('Google', 'NOUN'),
#   ('.', '.')],
#  [('Android', 'NOUN'),
#   ('has', 'VERB'),
#   ('been', 'VERB'),
#   ('the', 'DET'),
#   ('best-selling', 'ADJ'),
#   ('OS', 'NOUN'),
#   ('worldwide', 'NOUN'),
#   ('on', 'ADP'),
#   ('smartphones', 'NOUN'),
#   ('since', 'ADP'),
#   ('2011', 'NUM'),
#   ('and', 'CONJ'),
#   ('on', 'ADP'),
#   ('tablets', 'NOUN'),
#   ('since', 'ADP'),
#   ('2013', 'NUM'),
#   ('.', '.')],
#  [('Google', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Twitter', 'NOUN'),
#   ('made', 'VERB'),
#   ('a', 'DET'),
#   ('deal', 'NOUN'),
#   ('in', 'ADP'),
#   ('2015', 'NUM'),
#   ('that', 'DET'),
#   ('gave', 'VERB'),
#   ('Google', 'NOUN'),
#   ('access', 'NOUN'),
#   ('to', 'PRT'),
#   ('Twitter', 'NOUN'),
#   ("'s", 'PRT'),
#   ('firehose', 'NOUN'),
#   ('.', '.')],
#  [('Twitter', 'NOUN'),
#   ('is', 'VERB'),
#   ('an', 'DET'),
#   ('online', 'ADJ'),
#   ('news', 'NOUN'),
#   ('and', 'CONJ'),
#   ('social', 'ADJ'),
#   ('networking', 'NOUN'),
#   ('service', 'NOUN'),
#   ('on', 'ADP'),
#   ('which', 'DET'),
#   ('users', 'NOUN'),
#   ('post', 'NOUN'),
#   ('and', 'CONJ'),
#   ('interact', 'NOUN'),
#   ('with', 'ADP'),
#   ('messages', 'NOUN'),
#   ('known', 'VERB'),
#   ('as', 'ADP'),
#   ('tweets', 'NOUN'),
#   ('.', '.')],
#  [('Before', 'ADP'),
#   ('entering', 'VERB'),
#   ('politics', 'NOUN'),
#   (',', '.'),
#   ('Donald', 'NOUN'),
#   ('Trump', 'NOUN'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('domineering', 'ADJ'),
#   ('businessman', 'NOUN'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('television', 'NOUN'),
#   ('personality', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('2018', 'NUM'),
#   ('FIFA', 'NOUN'),
#   ('World', 'NOUN'),
#   ('Cup', 'NOUN'),
#   ('is', 'VERB'),
#   ('the', 'DET'),
#   ('21st', 'NUM'),
#   ('FIFA', 'NOUN'),
#   ('World', 'NOUN'),
#   ('Cup', 'NOUN'),
#   (',', '.'),
#   ('an', 'DET'),
#   ('international', 'ADJ'),
#   ('football', 'NOUN'),
#   ('tournament', 'NOUN'),
#   ('contested', 'VERB'),
#   ('once', 'ADV'),
#   ('every', 'DET'),
#   ('four', 'NUM'),
#   ('years', 'NOUN'),
#   ('.', '.')],
#  [('This', 'DET'),
#   ('is', 'VERB'),
#   ('the', 'DET'),
#   ('first', 'ADJ'),
#   ('World', 'NOUN'),
#   ('Cup', 'NOUN'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('held', 'VERB'),
#   ('in', 'ADP'),
#   ('Eastern', 'NOUN'),
#   ('Europe', 'NOUN'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('11th', 'NUM'),
#   ('time', 'NOUN'),
#   ('that', 'ADP'),
#   ('it', 'PRON'),
#   ('has', 'VERB'),
#   ('been', 'VERB'),
#   ('held', 'VERB'),
#   ('in', 'ADP'),
#   ('Europe', 'NOUN'),
#   ('.', '.')],
#  [('Show', 'VERB'),
#   ('me', 'PRON'),
#   ('the', 'DET'),
#   ('cheapest', 'ADJ'),
#   ('round', 'NOUN'),
#   ('trips', 'NOUN'),
#   ('from', 'ADP'),
#   ('Dallas', 'NOUN'),
#   ('to', 'PRT'),
#   ('Atlanta', 'VERB')],
#  [('I', 'PRON'),
#   ('would', 'VERB'),
#   ('like', 'VERB'),
#   ('to', 'PRT'),
#   ('see', 'VERB'),
#   ('flights', 'NOUN'),
#   ('from', 'ADP'),
#   ('Denver', 'NOUN'),
#   ('to', 'PRT'),
#   ('Philadelphia', 'NOUN'),
#   ('.', '.')],
#  [('Show', 'VERB'),
#   ('me', 'PRON'),
#   ('the', 'DET'),
#   ('price', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('flights', 'NOUN'),
#   ('leaving', 'VERB'),
#   ('Atlanta', 'NOUN'),
#   ('at', 'ADP'),
#   ('about', 'ADV'),
#   ('3', 'NUM'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('afternoon', 'NOUN'),
#   ('and', 'CONJ'),
#   ('arriving', 'NOUN'),
#   ('in', 'ADP'),
#   ('San', 'NOUN'),
#   ('Francisco', 'NOUN'),
#   ('.', '.')],
#  [('NASA', 'NOUN'),
#   ('invited', 'VERB'),
#   ('social', 'ADJ'),
#   ('media', 'NOUN'),
#   ('users', 'NOUN'),
#   ('to', 'PRT'),
#   ('experience', 'VERB'),
#   ('the', 'DET'),
#   ('launch', 'NOUN'),
#   ('of', 'ADP'),
#   ('ICESAT-2', 'NOUN'),
#   ('Satellite', 'NOUN'),
#   ('.', '.')]]

# %%
# list of untagged words from the sample test data provided
sample_test_tagged_words = [tup[0] for sent in sample_test_corpus_pos_tags for tup in sent]


# list of tagged words
sample_test_test_run_base = [tup for sent in sample_test_corpus_pos_tags for tup in sent]

# %%
sample_test_tagged_words
# Out:
# ['Android',
#  'is',
#  'a',
#  'mobile',
#  'operating',
#  'system',
#  'developed',
#  'by',
#  'Google',
#  '.',
#  'Android',
#  'has',
#  'been',
#  'the',
#  'best-selling',
#  'OS',
#  'worldwide',
#  'on',
#  'smartphones',
#  'since',
#  '2011',
#  'and',
#  'on',
#  'tablets',
#  'since',
#  '2013',
#  '.',
#  'Google',
#  'and',
#  'Twitter',
#  'made',
#  'a',
#  'deal',
#  'in',
#  '2015',
#  'that',
#  'gave',
#  'Google',
#  'access',
#  'to',
#  'Twitter',
#  "'s",
#  'firehose',
#  '.',
#  'Twitter',
#  'is',
#  'an',
#  'online',
#  'news',
#  'and',
#  'social',
#  'networking',
#  'service',
#  'on',
#  'which',
#  'users',
#  'post',
#  'and',
#  'interact',
#  'with',
#  'messages',
#  'known',
#  'as',
#  'tweets',
#  '.',
#  'Before',
#  'entering',
#  'politics',
#  ',',
#  'Donald',
#  'Trump',
#  'was',
#  'a',
#  'domineering',
#  'businessman',
#  'and',
#  'a',
#  'television',
#  'personality',
#  '.',
#  'The',
#  '2018',
#  'FIFA',
#  'World',
#  'Cup',
#  'is',
#  'the',
#  '21st',
#  'FIFA',
#  'World',
#  'Cup',
#  ',',
#  'an',
#  'international',
#  'football',
#  'tournament',
#  'contested',
#  'once',
#  'every',
#  'four',
#  'years',
#  '.',
#  'This',
#  'is',
#  'the',
#  'first',
#  'World',
#  'Cup',
#  'to',
#  'be',
#  'held',
#  'in',
#  'Eastern',
#  'Europe',
#  'and',
#  'the',
#  '11th',
#  'time',
#  'that',
#  'it',
#  'has',
#  'been',
#  'held',
#  'in',
#  'Europe',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'cheapest',
#  'round',
#  'trips',
#  'from',
#  'Dallas',
#  'to',
#  'Atlanta',
#  'I',
#  'would',
#  'like',
#  'to',
#  'see',
#  'flights',
#  'from',
#  'Denver',
#  'to',
#  'Philadelphia',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'price',
#  'of',
#  'the',
#  'flights',
#  'leaving',
#  'Atlanta',
#  'at',
#  'about',
#  '3',
#  'in',
#  'the',
#  'afternoon',
#  'and',
#  'arriving',
#  'in',
#  'San',
#  'Francisco',
#  '.',
#  'NASA',
#  'invited',
#  'social',
#  'media',
#  'users',
#  'to',
#  'experience',
#  'the',
#  'launch',
#  'of',
#  'ICESAT-2',
#  'Satellite',
#  '.']

# %% [markdown]
# ### 1. Testing the accuracy of Vanilla Viterbi on sample test data -

# %%
# tagging the test sentences
sample_test_tagged_seq = Vanilla_Viterbi(sample_test_tagged_words)

# Let's check the accuracy of the vanilla viterbi algorithm
sample_test_check = [i for i, j in zip(sample_test_tagged_seq, sample_test_test_run_base) if i == j]

vanilla_viterbi_accuracy_on_sample_test_data = len(sample_test_check)/len(sample_test_tagged_seq)

print("The accuracy of the Vanilla Viterbi Algorithm on the sample test data is -", vanilla_viterbi_accuracy_on_sample_test_data)
# Out:
# The accuracy of the Vanilla Viterbi Algorithm on the sample test data is - 0.7569060773480663

# %% [markdown]
# ### 2. Testing the accuracy of Vanilla_Viterbi_for_Unknown_Words on sample test data -

# %%
# tagging the test sentences
sample_test_unknown_word_tagged_seq = Vanilla_Viterbi_for_Unknown_Words(sample_test_tagged_words)

# accuracy
sample_test_unknown_word_check = [i for i, j in zip(sample_test_unknown_word_tagged_seq, sample_test_test_run_base) if i == j]

sample_test_optimized_viterbi_accuracy = len(sample_test_unknown_word_check)/len(sample_test_unknown_word_tagged_seq)

print("The accuracy of the Vanilla_Viterbi_for_Unknown_Words on the sample test data is -", sample_test_optimized_viterbi_accuracy)
# Out:
# The accuracy of the Vanilla_Viterbi_for_Unknown_Words on the sample test data is - 0.861878453038674

# %% [markdown]
# ### 3. Testing the accuracy of viterbi_backedup_by_trigram_tagger on sample test data -

# %%
# tagging the test sentences
sample_test_viterbi_trigram_tagged_seq = viterbi_backedup_by_trigram_tagger(sample_test_tagged_words)

# accuracy
sample_test_viterbi_trigram_check = [i for i, j in zip(sample_test_viterbi_trigram_tagged_seq, sample_test_test_run_base) if i == j]

sample_test_viterbi_trigram_accuracy = len(sample_test_viterbi_trigram_check)/len(sample_test_viterbi_trigram_tagged_seq)

print("The accuracy of the viterbi_backedup_by_trigram_tagger on the sample test data is -", sample_test_viterbi_trigram_accuracy)
# Out:
# The accuracy of the viterbi_backedup_by_trigram_tagger on the sample test data is - 0.9281767955801105

# %% [markdown]
# ### Comparing the accuracies of the 3 algorithm on sample test data -

# %%
acccuracy_on_sample_test_data = [['Vanilla Viterbi', vanilla_viterbi_accuracy_on_sample_test_data*100], 
                  ['Optimized Vanilla Viterbi', sample_test_optimized_viterbi_accuracy*100], 
                  ['Viterbi + Trigram_tagger', sample_test_viterbi_trigram_accuracy*100]]

sample_test_data_acccuracy_df = pd.DataFrame(acccuracy_on_sample_test_data, columns = ['Tagging_Algorithm', 'Tagging_Accuracy'])

sample_test_data_acccuracy_df.set_index('Tagging_Algorithm', drop = True, inplace = True)

sample_test_data_acccuracy_df
# Out:
#                            Tagging_Accuracy
# Tagging_Algorithm
# Vanilla Viterbi                   75.690608
# Optimized Vanilla Viterbi         86.187845
# Viterbi + Trigram_tagger          92.817680

# %%
sample_test_data_acccuracy_df.plot.line(rot = 90, legend = False)

# %% [markdown]
# ## List down cases which were incorrectly tagged by original POS tagger & got corrected by your modifications -

# %%
# test sentences

test_sentence_1 = 'Android is a mobile operating system developed by Google.'
test_sentence_2 = 'Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.'
test_sentence_3 = "Google and Twitter made a deal in 2015 that gave Google access to Twitter's firehose."
test_sentence_4 = 'Twitter is an online news and social networking service on which users post and interact with messages known as tweets.'
test_sentence_5 = 'Before entering politics, Donald Trump was a domineering businessman and a television personality.'
test_sentence_6 = 'The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years.'
test_sentence_7 = 'This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe.'
test_sentence_8 = 'Show me the cheapest round trips from Dallas to Atlanta'
test_sentence_9 = 'I would like to see flights from Denver to Philadelphia.'
test_sentence_10 = 'Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.'
test_sentence_11 = 'NASA invited social media users to experience the launch of ICESAT-2 Satellite.'

# %% [markdown]
# # Case - 1

# %%
# test_sentence_1 = 'Android is a mobile operating system developed by Google.'

words_test_sentence_1 = nltk.word_tokenize(test_sentence_1)

# pos tags with Vanilla_Viterbi
pos_tagged_sequence_with_vanilla_viterbi = Vanilla_Viterbi(words_test_sentence_1)
print("Tagging sequence with Vanilla_Viterbi -\n\n", pos_tagged_sequence_with_vanilla_viterbi)

print('\n')
print('-'*120)

# pos tags with viterbi_backedup_by_trigram_tagger
pos_tagged_sequence_with_viterbi_trigram = viterbi_backedup_by_trigram_tagger(words_test_sentence_1)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", pos_tagged_sequence_with_viterbi_trigram)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('Android', 'ADV'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'ADV'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.')]

# %%
cols = ['vanilla_viterbi_tags', 'viterbi_trigram_tags_with_corrections']
tags_correction_df_1 = pd.DataFrame(columns = cols)
tags_correction_df_1 = tags_correction_df_1.fillna(0)

tags_correction_df_1.vanilla_viterbi_tags = [tup for tup in pos_tagged_sequence_with_vanilla_viterbi]
tags_correction_df_1.viterbi_trigram_tags_with_corrections = [tup for tup in pos_tagged_sequence_with_viterbi_trigram]

tags_correction_df_1
# Out:
#   vanilla_viterbi_tags viterbi_trigram_tags_with_corrections
# 0       (Android, ADV)                       (Android, NOUN)
# 1           (is, VERB)                            (is, VERB)
# 2             (a, DET)                              (a, DET)
# 3        (mobile, ADJ)                         (mobile, ADJ)
# 4    (operating, NOUN)                     (operating, NOUN)
# 5       (system, NOUN)                        (system, NOUN)
# 6    (developed, VERB)                     (developed, VERB)
# 7            (by, ADP)                             (by, ADP)
# 8        (Google, ADV)                        (Google, NOUN)
# 9               (., .)                                (., .)

# %% [markdown]
# #### As we see above in the sample test sentence 1 the word 'Android' was tagged as PRT by vanilla viterbi. The modified algorithm of viterbi backed up by trigram tagger corrected this and tagged 'Android' as NOUN.

# %% [markdown]
# # Case - 2

# %%
# test_sentence_6 = 'The 2018 FIFA World Cup is the 21st FIFA World Cup, 
#                   an international football tournament contested once every four years.'

words_test_sentence_6 = nltk.word_tokenize(test_sentence_6)

# pos tags with Vanilla_Viterbi
pos_tagged_sequence_with_vanilla_viterbi_6 = Vanilla_Viterbi(words_test_sentence_6)
print("Tagging sequence with Vanilla_Viterbi -\n\n", pos_tagged_sequence_with_vanilla_viterbi_6)

print('\n')
print('-'*120)

# pos tags with viterbi_backedup_by_trigram_tagger
pos_tagged_sequence_with_viterbi_trigram_6 = viterbi_backedup_by_trigram_tagger(words_test_sentence_6)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", pos_tagged_sequence_with_viterbi_trigram_6)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('The', 'DET'), ('2018', 'ADV'), ('FIFA', 'ADV'), ('World', 'NOUN'), ('Cup', 'ADV'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'ADV'), ('FIFA', 'ADV'), ('World', 'NOUN'), ('Cup', 'ADV'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'ADV'), ('contested', 'ADV'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('The', 'DET'), ('2018', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'VERB'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.')]

# %%
tags_correction_df_6 = pd.DataFrame(columns = cols)
tags_correction_df_6 = tags_correction_df_6.fillna(0)

tags_correction_df_6.vanilla_viterbi_tags = [tup for tup in pos_tagged_sequence_with_vanilla_viterbi_6]
tags_correction_df_6.viterbi_trigram_tags_with_corrections = [tup for tup in pos_tagged_sequence_with_viterbi_trigram_6]

tags_correction_df_6
# Out:
#     vanilla_viterbi_tags viterbi_trigram_tags_with_corrections
# 0             (The, DET)                            (The, DET)
# 1            (2018, ADV)                           (2018, NUM)
# 2            (FIFA, ADV)                          (FIFA, NOUN)
# 3          (World, NOUN)                         (World, NOUN)
# 4             (Cup, ADV)                           (Cup, NOUN)
# 5             (is, VERB)                            (is, VERB)
# 6             (the, DET)                            (the, DET)
# 7            (21st, ADV)                           (21st, NUM)
# 8            (FIFA, ADV)                          (FIFA, NOUN)
# 9          (World, NOUN)                         (World, NOUN)
# 10            (Cup, ADV)                           (Cup, NOUN)
# 11                (,, .)                                (,, .)
# 12             (an, DET)                             (an, DET)
# 13  (international, ADJ)                  (international, ADJ)
# 14      (football, NOUN)                      (football, NOUN)
# 15     (tournament, ADV)                    (tournament, NOUN)
# 16      (contested, ADV)                     (contested, VERB)
# 17           (once, ADV)                           (once, ADV)
# 18          (every, DET)                          (every, DET)
# 19           (four, NUM)                           (four, NUM)
# 20         (years, NOUN)                         (years, NOUN)
# 21                (., .)                                (., .)

# %% [markdown]
# #### As we see above in the sample test sentence 6 the following words were incorrectly tagged by the vanilla viterbi algorithm -  '2018' - PRT, 'FIFA' - PRT, 'Cup' - PRT, '21st' - PRT, 'tournament' - PRT, 'contested' - PRT.
#
# #### The above words were corrected by viterbi backed up by the trigram tagger. The corrections were made as - '2018' - NUM, 'FIFA' - NOUN, 'Cup' - NOUN, '21st' - NUM, 'tournament' - NOUN, 'contested' - VERB.

# %% [markdown]
# # Case - 3

# %%
# test_sentence_8 = 'Show me the cheapest round trips from Dallas to Atlanta'

words_test_sentence_8 = nltk.word_tokenize(test_sentence_8)

# pos tags with Vanilla_Viterbi
pos_tagged_sequence_with_vanilla_viterbi_8 = Vanilla_Viterbi(words_test_sentence_8)
print("Tagging sequence with Vanilla_Viterbi -\n\n", pos_tagged_sequence_with_vanilla_viterbi_8)

print('\n')
print('-'*120)

# pos tags with viterbi_backedup_by_trigram_tagger
pos_tagged_sequence_with_viterbi_trigram_8 = viterbi_backedup_by_trigram_tagger(words_test_sentence_8)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", pos_tagged_sequence_with_viterbi_trigram_8)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'ADV'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN')]

# %%
tags_correction_df_8 = pd.DataFrame(columns = cols)
tags_correction_df_8 = tags_correction_df_8.fillna(0)

tags_correction_df_8.vanilla_viterbi_tags = [tup for tup in pos_tagged_sequence_with_vanilla_viterbi_8]
tags_correction_df_8.viterbi_trigram_tags_with_corrections = [tup for tup in pos_tagged_sequence_with_viterbi_trigram_8]

tags_correction_df_8
# Out:
#   vanilla_viterbi_tags viterbi_trigram_tags_with_corrections
# 0         (Show, NOUN)                          (Show, NOUN)
# 1           (me, PRON)                            (me, PRON)
# 2           (the, DET)                            (the, DET)
# 3      (cheapest, ADJ)                       (cheapest, ADJ)
# 4        (round, NOUN)                         (round, NOUN)
# 5         (trips, ADV)                         (trips, NOUN)
# 6          (from, ADP)                           (from, ADP)
# 7       (Dallas, NOUN)                        (Dallas, NOUN)
# 8            (to, PRT)                             (to, PRT)
# 9      (Atlanta, NOUN)                       (Atlanta, NOUN)

# %% [markdown]
# #### As we see in the sample test sentence 8, the vanilla viterbi tagged 'trips' as PRT. This was corrected by the modified viterbi algorithm (backed up by the trigram tagger) and tagged as NOUN.

# %% [markdown]
# #### Now lets see the tags and corrections for all the sample test sentences with both the methods.
#
# #### Method 1 - We used only the transition probability for unknown words.
# #### Method 2 - We used the viterbi algorithm and backed it up with the trigram tagger which was inturn backed up by the rule based regex tagger.

# %%
# Default Vanilla Viterbi
# pos tags with Vanilla_Viterbi
sample_test_tagged_sequence_with_vanilla_viterbi = Vanilla_Viterbi(sample_test_tagged_words)
print("Tagging sequence with Vanilla_Viterbi -\n\n", sample_test_tagged_sequence_with_vanilla_viterbi)

print('\n')
print('-'*120)

# Method 1 - pos tags with Vanilla_Viterbi_for_Unknown_Words
sample_test_tagged_sequence_unknown_words = Vanilla_Viterbi_for_Unknown_Words(sample_test_tagged_words)
print("Tagging sequence with viterbi using only transition probability for unknown words -\n\n", 
      sample_test_tagged_sequence_unknown_words)

print('\n')
print('-'*120)

# Method 2 - pos tags with viterbi_backedup_by_trigram_tagger
sample_test_tagged_sequence_with_viterbi_trigram = viterbi_backedup_by_trigram_tagger(sample_test_tagged_words)
print("Tagging sequence with viterbi_backedup_by_trigram_tagger -\n\n", sample_test_tagged_sequence_with_viterbi_trigram)
# Out:
# Tagging sequence with Vanilla_Viterbi -
#
#  [('Android', 'ADV'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'ADV'), ('.', '.'), ('Android', 'ADV'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'ADV'), ('worldwide', 'ADV'), ('on', 'ADP'), ('smartphones', 'ADV'), ('since', 'ADP'), ('2011', 'ADV'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'ADV'), ('.', '.'), ('Google', 'ADV'), ('and', 'CONJ'), ('Twitter', 'ADV'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'ADV'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'ADV'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'ADV'), ("'s", 'PRT'), ('firehose', 'ADV'), ('.', '.'), ('Twitter', 'ADV'), ('is', 'VERB'), ('an', 'DET'), ('online', 'ADV'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'ADV'), ('with', 'ADP'), ('messages', 'ADV'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'ADV'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'ADV'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'ADV'), ('.', '.'), ('The', 'DET'), ('2018', 'ADV'), ('FIFA', 'ADV'), ('World', 'NOUN'), ('Cup', 'ADV'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'ADV'), ('FIFA', 'ADV'), ('World', 'NOUN'), ('Cup', 'ADV'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'ADV'), ('contested', 'ADV'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'ADV'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'ADV'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'ADV'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'ADV'), ('invited', 'ADV'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'ADV'), ('Satellite', 'ADV'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi using only transition probability for unknown words -
#
#  [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'DET'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'DET'), ('since', 'ADP'), ('2011', 'DET'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'DET'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'DET'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'X'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'VERB'), ("'s", 'PRT'), ('firehose', 'VERB'), ('.', '.'), ('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'DET'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'DET'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'NOUN'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.'), ('The', 'DET'), ('2018', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'NOUN'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'NOUN'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'NOUN'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'DET'), ('Satellite', 'NOUN'), ('.', '.')]
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Tagging sequence with viterbi_backedup_by_trigram_tagger -
#
#  [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'VERB'), ('since', 'ADP'), ('2011', 'NUM'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'NUM'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'NUM'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'NOUN'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'NOUN'), ("'s", 'PRT'), ('firehose', 'NOUN'), ('.', '.'), ('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'VERB'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'NOUN'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'VERB'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.'), ('The', 'DET'), ('2018', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'VERB'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'VERB'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'VERB'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'NOUN'), ('Satellite', 'NOUN'), ('.', '.')]

# %%
# A dataframe showing - 
# 1. the actual tags using nltk.pos_tag_sent
# 2. words as tagged by vanilla viterbi
# 3. words as tagged by Vanilla_Viterbi_for_Unknown_Words - METHOD - 1
# 4. words as tagged by viterbi_backedup_by_trigram_tagger - METHOD - 2

cols1 = ['actual_tags', 'as_tagged_by_vanilla_viterbi', 'as_tagged_by_Vanilla_Viterbi_for_Unknown_Words',
            'as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger']

tags_comparison_df = pd.DataFrame(columns = cols1)
tags_comparison_df = tags_comparison_df.fillna(0)

# Actual tags
tags_comparison_df.actual_tags = [tup for tup in sample_test_test_run_base]

# tags by vanilla viterbi
tags_comparison_df.as_tagged_by_vanilla_viterbi = [tup for tup in sample_test_tagged_sequence_with_vanilla_viterbi]

# tags by Vanilla_Viterbi_for_Unknown_Words - METHOD - 1
tags_comparison_df.as_tagged_by_Vanilla_Viterbi_for_Unknown_Words = [tup for tup in sample_test_tagged_sequence_unknown_words]

# tags by viterbi_backedup_by_trigram_tagger - METHOD - 2
tags_comparison_df.as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger = [tup for tup in 
                                                                            sample_test_tagged_sequence_with_viterbi_trigram]

tags_comparison_df[tags_comparison_df.as_tagged_by_vanilla_viterbi != 
                   tags_comparison_df.as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger]
# Out:
#              actual_tags as_tagged_by_vanilla_viterbi  \
# 0        (Android, NOUN)               (Android, ADV)
# 8         (Google, NOUN)                (Google, ADV)
# 10       (Android, NOUN)               (Android, ADV)
# 15            (OS, NOUN)                    (OS, ADV)
# 16     (worldwide, NOUN)             (worldwide, ADV)
# 18   (smartphones, NOUN)           (smartphones, ADV)
# 20           (2011, NUM)                  (2011, ADV)
# 25           (2013, NUM)                  (2013, ADV)
# 27        (Google, NOUN)                (Google, ADV)
# 29       (Twitter, NOUN)               (Twitter, ADV)
# 34           (2015, NUM)                  (2015, ADV)
# 37        (Google, NOUN)                (Google, ADV)
# 40       (Twitter, NOUN)               (Twitter, ADV)
# 42      (firehose, NOUN)              (firehose, ADV)
# 44       (Twitter, NOUN)               (Twitter, ADV)
# 47         (online, ADJ)                (online, ADV)
# 58      (interact, NOUN)              (interact, ADV)
# 60      (messages, NOUN)              (messages, ADV)
# 63        (tweets, NOUN)                (tweets, ADV)
# 73    (domineering, ADJ)           (domineering, ADV)
# 78   (personality, NOUN)           (personality, ADV)
# 81           (2018, NUM)                  (2018, ADV)
# 82          (FIFA, NOUN)                  (FIFA, ADV)
# 84           (Cup, NOUN)                   (Cup, ADV)
# 87           (21st, NUM)                  (21st, ADV)
# 88          (FIFA, NOUN)                  (FIFA, ADV)
# 90           (Cup, NOUN)                   (Cup, ADV)
# 95    (tournament, NOUN)            (tournament, ADV)
# 96     (contested, VERB)             (contested, ADV)
# 107          (Cup, NOUN)                   (Cup, ADV)
# 131        (trips, NOUN)                 (trips, ADV)
# 163     (arriving, NOUN)              (arriving, ADV)
# 168         (NASA, NOUN)                  (NASA, ADV)
# 169      (invited, VERB)               (invited, ADV)
# 178     (ICESAT-2, NOUN)              (ICESAT-2, ADV)
# 179    (Satellite, NOUN)             (Satellite, ADV)
#
#     as_tagged_by_Vanilla_Viterbi_for_Unknown_Words  \
# 0                                  (Android, NOUN)
# 8                                    (Google, DET)
# 10                                 (Android, NOUN)
# 15                                      (OS, NOUN)
# 16                               (worldwide, NOUN)
# 18                              (smartphones, DET)
# 20                                     (2011, DET)
# 25                                     (2013, DET)
# 27                                  (Google, NOUN)
# 29                                 (Twitter, NOUN)
# 34                                     (2015, DET)
# 37                                     (Google, X)
# 40                                 (Twitter, VERB)
# 42                                (firehose, VERB)
# 44                                 (Twitter, NOUN)
# 47                                  (online, NOUN)
# 58                                (interact, NOUN)
# 60                                 (messages, DET)
# 63                                   (tweets, DET)
# 73                             (domineering, NOUN)
# 78                             (personality, NOUN)
# 81                                    (2018, NOUN)
# 82                                    (FIFA, NOUN)
# 84                                     (Cup, NOUN)
# 87                                    (21st, NOUN)
# 88                                    (FIFA, NOUN)
# 90                                     (Cup, NOUN)
# 95                              (tournament, NOUN)
# 96                               (contested, NOUN)
# 107                                    (Cup, NOUN)
# 131                                  (trips, NOUN)
# 163                               (arriving, NOUN)
# 168                                   (NASA, NOUN)
# 169                                (invited, NOUN)
# 178                                (ICESAT-2, DET)
# 179                              (Satellite, NOUN)
#
#     as_tagged_by_Vanilla_Viterbi_backed_by_trigram_tagger
# 0                                      (Android, NOUN)
# 8                                       (Google, NOUN)
# 10                                     (Android, NOUN)
# 15                                          (OS, NOUN)
# 16                                   (worldwide, NOUN)
# 18                                 (smartphones, VERB)
# 20                                         (2011, NUM)
# 25                                         (2013, NUM)
# 27                                      (Google, NOUN)
# 29                                     (Twitter, NOUN)
# 34                                         (2015, NUM)
# 37                                      (Google, NOUN)
# 40                                     (Twitter, NOUN)
# 42                                    (firehose, NOUN)
# 44                                     (Twitter, NOUN)
# 47                                      (online, NOUN)
# 58                                    (interact, NOUN)
# 60                                    (messages, VERB)
# 63                                      (tweets, NOUN)
# 73                                 (domineering, VERB)
# 78                                 (personality, NOUN)
# 81                                         (2018, NUM)
# 82                                        (FIFA, NOUN)
# 84                                         (Cup, NOUN)
# 87                                         (21st, NUM)
# 88                                        (FIFA, NOUN)
# 90                                         (Cup, NOUN)
# 95                                  (tournament, NOUN)
# 96                                   (contested, VERB)
# 107                                        (Cup, NOUN)
# 131                                      (trips, NOUN)
# 163                                   (arriving, VERB)
# 168                                       (NASA, NOUN)
# 169                                    (invited, VERB)
# 178                                   (ICESAT-2, NOUN)
# 179                                  (Satellite, NOUN)

# %% [markdown]
# # Conclusion -
#
# #### Thus we see that most of the words that were incorrectly tagged by the vanilla viterbi algorithm were corrected by the viterbi algorithm backed up by the trigram tagger.
#
# **In this analysis we used 2 modification techniques for the original vanilla viterbi -**
#
# #### Method 1 -
#     - We used only the transition probability for unknown words.
#     - This method showed an increase in the accuracy (94.1%) but still had some incorrect classification.
#     - The accuracy could be increased further and we turned two a second modification in method-2 below.
#
# #### Method 2 -
#     - We used the viterbi algorithm and backed it up with the trigram tagger which was inturn backed up by the rule based
#     regex tagger.
#     - This gave us an accuracy of 95.82% on the test data.
#     - Also on testing this model on the provided sample test data, it achieved an accuracy of 92.81% and comes out to be
#     the winner.
